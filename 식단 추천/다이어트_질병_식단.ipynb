# %%
from google.colab import drive 
drive.mount('/content/gdrive/')
# Out:
# Mounted at /content/gdrive/

# %%
import pandas as pd
data=pd.read_csv('/content/gdrive/MyDrive/영양성분표/영양성분표_전처리_완료.csv')

# %%
data.head()
# Out:
#    FOOD_CD DESC_KOR MAKER_NAME GROUP_NAME  SERVING_SIZE  NUTR_CONT1  \
# 0  D000006     꿩불고기          -         반찬           500      368.80
# 1  D000007      닭갈비          -         반찬           400      595.61
# 2  D000009      닭꼬치          -         반찬            70      176.72
# 3  D000010     더덕구이          -         반찬           100      184.00
# 4  D000011     도미구이          -         반찬           250      397.00
#
#    NUTR_CONT2  NUTR_CONT3  NUTR_CONT4  NUTR_CONT5  NUTR_CONT6  NUTR_CONT7  \
# 0       39.70       33.50        8.50       16.90     1264.31      106.18
# 1       44.90       45.90       25.80       21.20     1535.83      193.40
# 2       13.35       11.56        8.57        3.15      286.91       31.44
# 3       31.10        3.10        5.20       11.60      743.37        0.12
# 4        2.10       61.10       16.50        0.00     1582.17      211.24
#
#    NUTR_CONT8  NUTR_CONT9
# 0        1.90        0.10
# 1        6.00        0.20
# 2        2.32        0.04
# ...

# %%
data=data.drop(["FOOD_CD","MAKER_NAME","SERVING_SIZE","NUTR_CONT5",	"NUTR_CONT6",	"NUTR_CONT7",	"NUTR_CONT8",	"NUTR_CONT9"],axis=1)

# %%
data
# Out:
#     DESC_KOR GROUP_NAME  NUTR_CONT1  NUTR_CONT2  NUTR_CONT3  NUTR_CONT4
# 0       꿩불고기         반찬      368.80       39.70       33.50        8.50
# 1        닭갈비         반찬      595.61       44.90       45.90       25.80
# 2        닭꼬치         반찬      176.72       13.35       11.56        8.57
# 3       더덕구이         반찬      184.00       31.10        3.10        5.20
# 4       도미구이         반찬      397.00        2.10       61.10       16.50
# ..       ...        ...         ...         ...         ...         ...
# 733    오징어튀김         반찬      505.71       33.65       18.56       32.99
# 734     채소튀김         반찬      404.63       36.83        3.25       27.14
# 735     치킨너겟         반찬      468.40       14.93       22.47       35.42
# 736      탕수육         반찬      358.97       24.84       27.21       16.75
# 737   후라이드치킨         반찬      530.04       21.29       35.47       33.67
#
# [738 rows x 6 columns]

# %%
data.columns
# Out:
# Index(['DESC_KOR', 'GROUP_NAME', 'NUTR_CONT1', 'NUTR_CONT2', 'NUTR_CONT3',
#        'NUTR_CONT4'],
#       dtype='object')

# %%
data=data.rename(columns={'DESC_KOR':'음식', 'GROUP_NAME':'분류', 'NUTR_CONT1':'열량','NUTR_CONT2':'탄수화물', 'NUTR_CONT3':'단백질',
       'NUTR_CONT4':'지방'})

# %%
data.head()
# Out:
#      음식  분류      열량   탄수화물    단백질     지방
# 0  꿩불고기  반찬  368.80  39.70  33.50   8.50
# 1   닭갈비  반찬  595.61  44.90  45.90  25.80
# 2   닭꼬치  반찬  176.72  13.35  11.56   8.57
# 3  더덕구이  반찬  184.00  31.10   3.10   5.20
# 4  도미구이  반찬  397.00   2.10  61.10  16.50

# %%
print(data.iloc[0])
# Out:
# 음식       꿩불고기
# 분류         반찬
# 열량      368.8
# 탄수화물     39.7
# 단백질      33.5
# 지방        8.5
# Name: 0, dtype: object

# %%
#list(combinations(nums,3))

rice=[]
i_rice=[]
soup=[]
i_soup=[]
side=[]
i_side=[]

for i in range(len(data['분류'])):
  if data['분류'][i]=="반찬":
    side.append(data['음식'][i])
    i_side.append(data.iloc[i])
  elif data['분류'][i]=="국":
    soup.append(data['음식'][i])
    i_soup.append(data.iloc[i])
  else:
    rice.append(data['음식'][i])
    i_rice.append(data.iloc[i])

print(len(rice))
print(len(soup))
print(len(side))
# Out:
# 142
# 142
# 454

# %%
soup
# Out:
# ['곰치국',
#  '김치국',
#  '떡만둣국',
#  '만둣국',
#  '맑은감자국',
#  '매생이국',
#  '무된장국',
#  '미소된장국',
#  '바지락조개국',
#  '뼈다귀해장국',
#  '선지해장국',
#  '소고기무국',
#  '소고기미역국',
#  '순대국',
#  '시래기된장국',
#  '올갱이국',
#  '우거지해장국',
#  '우렁된장국',
#  '탕국',
#  '홍합미역국',
#  '황태해장국',
#  '소고기샤브샤브',
#  '한방오리백숙',
#  '갈낙탕',
#  '곰탕',
#  '광어매운탕',
#  '낙지탕',
#  '대구매운탕',
#  '대구지리탕',
#  '메기매운탕',
#  '복지리탕',
#  '소탕',
#  '아구탕',
#  '어탕',
#  '연포탕',
#  '우럭매운탕',
#  '육탕',
#  '전복탕',
#  '조기매운탕',
#  '짱뚱어탕',
#  '추어탕',
#  '해물탕',
#  '갈비탕',
#  '감자된장국',
#  '감잣국',
#  '굴무국',
#  '근대된장국',
#  '김치콩나물국',
#  '김칫국',
#  '꼬리곰탕',
#  '냉이된장국',
#  '달걀국',
#  '닭개장',
#  '닭곰탕',
#  '대합미역국',
#  '도가니탕',
#  '동태국',
#  '메밀묵국',
#  '무시래기된장국',
#  '미역국',
#  '미역냉국',
#  '미역된장국',
#  '미역오이냉국',
#  '배추된장국',
#  '북엇국',
#  '뼈해장국',
#  '사골국',
#  '삼계탕',
#  '새우미역국',
#  '새우탕',
#  '선짓국(선지해장국)',
#  '설렁탕',
#  '쇠고기무국',
#  '쇠고기미역국',
#  '쇠고기배춧국',
#  '순댓국',
#  '순두부달걀탕',
#  '시금치된장국',
#  '쑥된장국',
#  '아욱된장국',
#  '애호박된장국',
#  '어묵국',
#  '얼갈이배춧국',
#  '오이냉국',
#  '오징어국',
#  '우거지곰탕',
#  '우거지된장국',
#  '육개장',
# ...

# %%
from itertools import product

meal=[rice,soup,side]

all_m=list(product(*meal))

# %%
print(len(all_m))
# Out:
# 9154456

# %% [markdown]
# ### 데이터 9,154,456개

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
all_m
# Out:
# [('굴국밥', '곰치국', '꿩불고기'),
#  ('굴국밥', '곰치국', '닭갈비'),
#  ('굴국밥', '곰치국', '닭꼬치'),
#  ('굴국밥', '곰치국', '더덕구이'),
#  ('굴국밥', '곰치국', '도미구이'),
#  ('굴국밥', '곰치국', '돼지갈비'),
#  ('굴국밥', '곰치국', '병어구이'),
#  ('굴국밥', '곰치국', '불고기'),
#  ('굴국밥', '곰치국', '붕장어소금구이'),
#  ('굴국밥', '곰치국', '소양념갈비구이'),
#  ('굴국밥', '곰치국', '양념왕갈비'),
#  ('굴국밥', '곰치국', '양념장어구이'),
#  ('굴국밥', '곰치국', '임연수구이'),
#  ('굴국밥', '곰치국', '짚불구이곰장어'),
#  ('굴국밥', '곰치국', '햄버그스테이크'),
#  ('굴국밥', '곰치국', '황태구이'),
#  ('굴국밥', '곰치국', '훈제오리'),
#  ('굴국밥', '곰치국', '게국지'),
#  ('굴국밥', '곰치국', '고추잡채'),
#  ('굴국밥', '곰치국', '난자완스'),
#  ('굴국밥', '곰치국', '도토리묵말이'),
#  ('굴국밥', '곰치국', '라조기'),
#  ('굴국밥', '곰치국', '물회'),
#  ('굴국밥', '곰치국', '생선물회'),
#  ('굴국밥', '곰치국', '오징어순대'),
#  ('굴국밥', '곰치국', '초당순두부'),
#  ('굴국밥', '곰치국', '해파리냉채'),
#  ('굴국밥', '곰치국', '고들빼기'),
#  ('굴국밥', '곰치국', '열무얼갈이김치'),
#  ('굴국밥', '곰치국', '미나리나물'),
#  ('굴국밥', '곰치국', '취나물'),
#  ('굴국밥', '곰치국', '콩나물'),
#  ('굴국밥', '곰치국', '골뱅이무침'),
#  ('굴국밥', '곰치국', '노각무침'),
#  ('굴국밥', '곰치국', '단무지무침'),
#  ('굴국밥', '곰치국', '달래나물무침'),
# ...

# %%
all_m[0][0]
# Out:
# '굴국밥'

# %%
#밥 국 반찬

# %%
i_rice[0]
# Out:
# 음식        굴국밥
# 분류          밥
# 열량      683.0
# 탄수화물     88.4
# 단백질      42.4
# 지방       17.8
# Name: 19, dtype: object

# %%
food_combi=pd.DataFrame(columns={"음식","열량","탄수화물","단백질","지방"})

# NUTR_CONT1':'열량','NUTR_CONT2':'탄수화물', 'NUTR_CONT3':'단백질','NUTR_CONT4':'지방'

from tqdm.notebook import tqdm

for i in tqdm(range(0,100000)):
  nr1=0
  nr2=0
  nr3=0
  nr4=0
  ri=rice.index(all_m[i][0])
  so=soup.index(all_m[i][1])
  si=side.index(all_m[i][2])
  nr1=int(i_rice[ri]["열량"])+int(i_soup[so]["열량"])+int(i_side[si]["열량"])
  nr2=int(i_rice[ri]["탄수화물"])+int(i_soup[so]["탄수화물"])+int(i_side[si]["탄수화물"])
  nr3=int(i_rice[ri]["단백질"])+int(i_soup[so]["단백질"])+int(i_side[si]["단백질"])
  nr4=int(i_rice[ri]["지방"])+int(i_soup[so]["지방"])+int(i_side[si]["지방"])
  combi={"음식":all_m[i],"열량":nr1,"탄수화물":nr2,"단백질":nr3,"지방":nr4}   
  food_combi=food_combi.append(combi,ignore_index=True)
food_combi=food_combi[["음식","열량","탄수화물","단백질","지방"]] 

dataframe=pd.DataFrame(food_combi)

dataframe.to_csv("/content/gdrive/MyDrive/캡스톤/coco/식품영양성분/영양성분표_밥국반찬SET_100000.csv",index=False, header=True)

# %%
food_combi=pd.DataFrame(columns={"음식","열량","탄수화물","단백질","지방"})

# NUTR_CONT1':'열량','NUTR_CONT2':'탄수화물', 'NUTR_CONT3':'단백질','NUTR_CONT4':'지방'

from tqdm.notebook import tqdm

for i in tqdm(range(100000,200000)):
  nr1=0
  nr2=0
  nr3=0
  nr4=0
  ri=rice.index(all_m[i][0])
  so=soup.index(all_m[i][1])
  si=side.index(all_m[i][2])
  nr1=int(i_rice[ri]["열량"])+int(i_soup[so]["열량"])+int(i_side[si]["열량"])
  nr2=int(i_rice[ri]["탄수화물"])+int(i_soup[so]["탄수화물"])+int(i_side[si]["탄수화물"])
  nr3=int(i_rice[ri]["단백질"])+int(i_soup[so]["단백질"])+int(i_side[si]["단백질"])
  nr4=int(i_rice[ri]["지방"])+int(i_soup[so]["지방"])+int(i_side[si]["지방"])
  combi={"음식":all_m[i],"열량":nr1,"탄수화물":nr2,"단백질":nr3,"지방":nr4}   
  food_combi=food_combi.append(combi,ignore_index=True)
food_combi=food_combi[["음식","열량","탄수화물","단백질","지방"]] 

dataframe=pd.DataFrame(food_combi)

dataframe.to_csv("/content/gdrive/MyDrive/캡스톤/coco/식품영양성분/영양성분표_밥국반찬SET_200000.csv",index=False, header=True)
# Out:
#   0%|          | 0/100000 [00:00<?, ?it/s]

# %%
food_combi=pd.DataFrame(columns={"음식","열량","탄수화물","단백질","지방"})

# NUTR_CONT1':'열량','NUTR_CONT2':'탄수화물', 'NUTR_CONT3':'단백질','NUTR_CONT4':'지방'

from tqdm.notebook import tqdm

for i in tqdm(range(1100000,1200000)):
  nr1=0
  nr2=0
  nr3=0
  nr4=0
  ri=rice.index(all_m[i][0])
  so=soup.index(all_m[i][1])
  si=side.index(all_m[i][2])
  nr1=int(i_rice[ri]["열량"])+int(i_soup[so]["열량"])+int(i_side[si]["열량"])
  nr2=int(i_rice[ri]["탄수화물"])+int(i_soup[so]["탄수화물"])+int(i_side[si]["탄수화물"])
  nr3=int(i_rice[ri]["단백질"])+int(i_soup[so]["단백질"])+int(i_side[si]["단백질"])
  nr4=int(i_rice[ri]["지방"])+int(i_soup[so]["지방"])+int(i_side[si]["지방"])
  combi={"음식":all_m[i],"열량":nr1,"탄수화물":nr2,"단백질":nr3,"지방":nr4}   
  food_combi=food_combi.append(combi,ignore_index=True)
food_combi=food_combi[["음식","열량","탄수화물","단백질","지방"]] 

dataframe=pd.DataFrame(food_combi)

dataframe.to_csv("/content/gdrive/MyDrive/캡스톤/coco/식품영양성분/영양성분표_밥국반찬SET_1200000.csv",index=False, header=True)
# Out:
#   0%|          | 0/100000 [00:00<?, ?it/s]

# %%
food_combi=pd.DataFrame(columns={"음식","열량","탄수화물","단백질","지방"})

# NUTR_CONT1':'열량','NUTR_CONT2':'탄수화물', 'NUTR_CONT3':'단백질','NUTR_CONT4':'지방'

from tqdm.notebook import tqdm

for i in tqdm(range(1500000,1600000)):
  nr1=0
  nr2=0
  nr3=0
  nr4=0
  ri=rice.index(all_m[i][0])
  so=soup.index(all_m[i][1])
  si=side.index(all_m[i][2])
  nr1=int(i_rice[ri]["열량"])+int(i_soup[so]["열량"])+int(i_side[si]["열량"])
  nr2=int(i_rice[ri]["탄수화물"])+int(i_soup[so]["탄수화물"])+int(i_side[si]["탄수화물"])
  nr3=int(i_rice[ri]["단백질"])+int(i_soup[so]["단백질"])+int(i_side[si]["단백질"])
  nr4=int(i_rice[ri]["지방"])+int(i_soup[so]["지방"])+int(i_side[si]["지방"])
  combi={"음식":all_m[i],"열량":nr1,"탄수화물":nr2,"단백질":nr3,"지방":nr4}   
  food_combi=food_combi.append(combi,ignore_index=True)
food_combi=food_combi[["음식","열량","탄수화물","단백질","지방"]] 

dataframe=pd.DataFrame(food_combi)

dataframe.to_csv("/content/gdrive/MyDrive/캡스톤/coco/식품영양성분/영양성분표_밥국반찬SET_1600000.csv",index=False, header=True)
# Out:
#   0%|          | 0/100000 [00:00<?, ?it/s]

# %%
food_combi=pd.DataFrame(columns={"음식","열량","탄수화물","단백질","지방"})

# NUTR_CONT1':'열량','NUTR_CONT2':'탄수화물', 'NUTR_CONT3':'단백질','NUTR_CONT4':'지방'

from tqdm.notebook import tqdm

for i in tqdm(range(1900000,2000000)):
  nr1=0
  nr2=0
  nr3=0
  nr4=0
  ri=rice.index(all_m[i][0])
  so=soup.index(all_m[i][1])
  si=side.index(all_m[i][2])
  nr1=int(i_rice[ri]["열량"])+int(i_soup[so]["열량"])+int(i_side[si]["열량"])
  nr2=int(i_rice[ri]["탄수화물"])+int(i_soup[so]["탄수화물"])+int(i_side[si]["탄수화물"])
  nr3=int(i_rice[ri]["단백질"])+int(i_soup[so]["단백질"])+int(i_side[si]["단백질"])
  nr4=int(i_rice[ri]["지방"])+int(i_soup[so]["지방"])+int(i_side[si]["지방"])
  combi={"음식":all_m[i],"열량":nr1,"탄수화물":nr2,"단백질":nr3,"지방":nr4}   
  food_combi=food_combi.append(combi,ignore_index=True)
food_combi=food_combi[["음식","열량","탄수화물","단백질","지방"]] 

dataframe=pd.DataFrame(food_combi)

dataframe.to_csv("/content/gdrive/MyDrive/캡스톤/coco/식품영양성분/영양성분표_밥국반찬SET_2000000.csv",index=False, header=True)
# Out:
#   0%|          | 0/100000 [00:00<?, ?it/s]

# %%
food_combi=pd.DataFrame(columns={"음식","열량","탄수화물","단백질","지방"})

# NUTR_CONT1':'열량','NUTR_CONT2':'탄수화물', 'NUTR_CONT3':'단백질','NUTR_CONT4':'지방'

from tqdm.notebook import tqdm

for i in tqdm(range(2000000,2100000)):
  nr1=0
  nr2=0
  nr3=0
  nr4=0
  ri=rice.index(all_m[i][0])
  so=soup.index(all_m[i][1])
  si=side.index(all_m[i][2])
  nr1=int(i_rice[ri]["열량"])+int(i_soup[so]["열량"])+int(i_side[si]["열량"])
  nr2=int(i_rice[ri]["탄수화물"])+int(i_soup[so]["탄수화물"])+int(i_side[si]["탄수화물"])
  nr3=int(i_rice[ri]["단백질"])+int(i_soup[so]["단백질"])+int(i_side[si]["단백질"])
  nr4=int(i_rice[ri]["지방"])+int(i_soup[so]["지방"])+int(i_side[si]["지방"])
  combi={"음식":all_m[i],"열량":nr1,"탄수화물":nr2,"단백질":nr3,"지방":nr4}   
  food_combi=food_combi.append(combi,ignore_index=True)
food_combi=food_combi[["음식","열량","탄수화물","단백질","지방"]] 

dataframe=pd.DataFrame(food_combi)

dataframe.to_csv("/content/gdrive/MyDrive/캡스톤/coco/식품영양성분/영양성분표_밥국반찬SET_2100000.csv",index=False, header=True)
# Out:
#   0%|          | 0/100000 [00:00<?, ?it/s]

# %%
food_combi=pd.DataFrame(columns={"음식","열량","탄수화물","단백질","지방"})

# NUTR_CONT1':'열량','NUTR_CONT2':'탄수화물', 'NUTR_CONT3':'단백질','NUTR_CONT4':'지방'

from tqdm.notebook import tqdm

for i in tqdm(range(2100000,2200000)):
  nr1=0
  nr2=0
  nr3=0
  nr4=0
  ri=rice.index(all_m[i][0])
  so=soup.index(all_m[i][1])
  si=side.index(all_m[i][2])
  nr1=int(i_rice[ri]["열량"])+int(i_soup[so]["열량"])+int(i_side[si]["열량"])
  nr2=int(i_rice[ri]["탄수화물"])+int(i_soup[so]["탄수화물"])+int(i_side[si]["탄수화물"])
  nr3=int(i_rice[ri]["단백질"])+int(i_soup[so]["단백질"])+int(i_side[si]["단백질"])
  nr4=int(i_rice[ri]["지방"])+int(i_soup[so]["지방"])+int(i_side[si]["지방"])
  combi={"음식":all_m[i],"열량":nr1,"탄수화물":nr2,"단백질":nr3,"지방":nr4}   
  food_combi=food_combi.append(combi,ignore_index=True)
food_combi=food_combi[["음식","열량","탄수화물","단백질","지방"]] 

dataframe=pd.DataFrame(food_combi)

dataframe.to_csv("/content/gdrive/MyDrive/캡스톤/coco/식품영양성분/영양성분표_밥국반찬SET_2200000.csv",index=False, header=True)
# Out:
#   0%|          | 0/100000 [00:00<?, ?it/s]

# %%
food_combi=pd.DataFrame(columns={"음식","열량","탄수화물","단백질","지방"})

# NUTR_CONT1':'열량','NUTR_CONT2':'탄수화물', 'NUTR_CONT3':'단백질','NUTR_CONT4':'지방'

from tqdm.notebook import tqdm

for i in tqdm(range(2200000,2300000)):
  nr1=0
  nr2=0
  nr3=0
  nr4=0
  ri=rice.index(all_m[i][0])
  so=soup.index(all_m[i][1])
  si=side.index(all_m[i][2])
  nr1=int(i_rice[ri]["열량"])+int(i_soup[so]["열량"])+int(i_side[si]["열량"])
  nr2=int(i_rice[ri]["탄수화물"])+int(i_soup[so]["탄수화물"])+int(i_side[si]["탄수화물"])
  nr3=int(i_rice[ri]["단백질"])+int(i_soup[so]["단백질"])+int(i_side[si]["단백질"])
  nr4=int(i_rice[ri]["지방"])+int(i_soup[so]["지방"])+int(i_side[si]["지방"])
  combi={"음식":all_m[i],"열량":nr1,"탄수화물":nr2,"단백질":nr3,"지방":nr4}   
  food_combi=food_combi.append(combi,ignore_index=True)
food_combi=food_combi[["음식","열량","탄수화물","단백질","지방"]] 

dataframe=pd.DataFrame(food_combi)

dataframe.to_csv("/content/gdrive/MyDrive/캡스톤/coco/식품영양성분/영양성분표_밥국반찬SET_2300000.csv",index=False, header=True)
# Out:
#   0%|          | 0/100000 [00:00<?, ?it/s]

# %%
food_combi=pd.DataFrame(columns={"음식","열량","탄수화물","단백질","지방"})

# NUTR_CONT1':'열량','NUTR_CONT2':'탄수화물', 'NUTR_CONT3':'단백질','NUTR_CONT4':'지방'

from tqdm.notebook import tqdm

for i in tqdm(range(2300000,2400000)):
  nr1=0
  nr2=0
  nr3=0
  nr4=0
  ri=rice.index(all_m[i][0])
  so=soup.index(all_m[i][1])
  si=side.index(all_m[i][2])
  nr1=int(i_rice[ri]["열량"])+int(i_soup[so]["열량"])+int(i_side[si]["열량"])
  nr2=int(i_rice[ri]["탄수화물"])+int(i_soup[so]["탄수화물"])+int(i_side[si]["탄수화물"])
  nr3=int(i_rice[ri]["단백질"])+int(i_soup[so]["단백질"])+int(i_side[si]["단백질"])
  nr4=int(i_rice[ri]["지방"])+int(i_soup[so]["지방"])+int(i_side[si]["지방"])
  combi={"음식":all_m[i],"열량":nr1,"탄수화물":nr2,"단백질":nr3,"지방":nr4}   
  food_combi=food_combi.append(combi,ignore_index=True)
food_combi=food_combi[["음식","열량","탄수화물","단백질","지방"]] 

dataframe=pd.DataFrame(food_combi)

dataframe.to_csv("/content/gdrive/MyDrive/캡스톤/coco/식품영양성분/영양성분표_밥국반찬SET_2400000.csv",index=False, header=True)
# Out:
#   0%|          | 0/100000 [00:00<?, ?it/s]

# %%
food_combi=pd.DataFrame(columns={"음식","열량","탄수화물","단백질","지방"})

# NUTR_CONT1':'열량','NUTR_CONT2':'탄수화물', 'NUTR_CONT3':'단백질','NUTR_CONT4':'지방'

from tqdm.notebook import tqdm

for i in tqdm(range(2400000,2500000)):
  nr1=0
  nr2=0
  nr3=0
  nr4=0
  ri=rice.index(all_m[i][0])
  so=soup.index(all_m[i][1])
  si=side.index(all_m[i][2])
  nr1=int(i_rice[ri]["열량"])+int(i_soup[so]["열량"])+int(i_side[si]["열량"])
  nr2=int(i_rice[ri]["탄수화물"])+int(i_soup[so]["탄수화물"])+int(i_side[si]["탄수화물"])
  nr3=int(i_rice[ri]["단백질"])+int(i_soup[so]["단백질"])+int(i_side[si]["단백질"])
  nr4=int(i_rice[ri]["지방"])+int(i_soup[so]["지방"])+int(i_side[si]["지방"])
  combi={"음식":all_m[i],"열량":nr1,"탄수화물":nr2,"단백질":nr3,"지방":nr4}   
  food_combi=food_combi.append(combi,ignore_index=True)
food_combi=food_combi[["음식","열량","탄수화물","단백질","지방"]] 

dataframe=pd.DataFrame(food_combi)

dataframe.to_csv("/content/gdrive/MyDrive/캡스톤/coco/식품영양성분/영양성분표_밥국반찬SET_2500000.csv",index=False, header=True)
# Out:
#   0%|          | 0/100000 [00:00<?, ?it/s]

# %%
food_combi=pd.DataFrame(columns={"음식","열량","탄수화물","단백질","지방"})

# NUTR_CONT1':'열량','NUTR_CONT2':'탄수화물', 'NUTR_CONT3':'단백질','NUTR_CONT4':'지방'

from tqdm.notebook import tqdm

for i in tqdm(range(2500000,2600000)):
  nr1=0
  nr2=0
  nr3=0
  nr4=0
  ri=rice.index(all_m[i][0])
  so=soup.index(all_m[i][1])
  si=side.index(all_m[i][2])
  nr1=int(i_rice[ri]["열량"])+int(i_soup[so]["열량"])+int(i_side[si]["열량"])
  nr2=int(i_rice[ri]["탄수화물"])+int(i_soup[so]["탄수화물"])+int(i_side[si]["탄수화물"])
  nr3=int(i_rice[ri]["단백질"])+int(i_soup[so]["단백질"])+int(i_side[si]["단백질"])
  nr4=int(i_rice[ri]["지방"])+int(i_soup[so]["지방"])+int(i_side[si]["지방"])
  combi={"음식":all_m[i],"열량":nr1,"탄수화물":nr2,"단백질":nr3,"지방":nr4}   
  food_combi=food_combi.append(combi,ignore_index=True)
food_combi=food_combi[["음식","열량","탄수화물","단백질","지방"]] 

dataframe=pd.DataFrame(food_combi)

dataframe.to_csv("/content/gdrive/MyDrive/캡스톤/coco/식품영양성분/영양성분표_밥국반찬SET_2600000.csv",index=False, header=True)
# Out:
#   0%|          | 0/100000 [00:00<?, ?it/s]

# %%
food_combi=pd.DataFrame(columns={"음식","열량","탄수화물","단백질","지방"})

# NUTR_CONT1':'열량','NUTR_CONT2':'탄수화물', 'NUTR_CONT3':'단백질','NUTR_CONT4':'지방'

from tqdm.notebook import tqdm

for i in tqdm(range(2600000,2700000)):
  nr1=0
  nr2=0
  nr3=0
  nr4=0
  ri=rice.index(all_m[i][0])
  so=soup.index(all_m[i][1])
  si=side.index(all_m[i][2])
  nr1=int(i_rice[ri]["열량"])+int(i_soup[so]["열량"])+int(i_side[si]["열량"])
  nr2=int(i_rice[ri]["탄수화물"])+int(i_soup[so]["탄수화물"])+int(i_side[si]["탄수화물"])
  nr3=int(i_rice[ri]["단백질"])+int(i_soup[so]["단백질"])+int(i_side[si]["단백질"])
  nr4=int(i_rice[ri]["지방"])+int(i_soup[so]["지방"])+int(i_side[si]["지방"])
  combi={"음식":all_m[i],"열량":nr1,"탄수화물":nr2,"단백질":nr3,"지방":nr4}   
  food_combi=food_combi.append(combi,ignore_index=True)
food_combi=food_combi[["음식","열량","탄수화물","단백질","지방"]] 

dataframe=pd.DataFrame(food_combi)

dataframe.to_csv("/content/gdrive/MyDrive/캡스톤/coco/식품영양성분/영양성분표_밥국반찬SET_2700000.csv",index=False, header=True)
# Out:
#   0%|          | 0/100000 [00:00<?, ?it/s]

# %%
food_combi=pd.DataFrame(columns={"음식","열량","탄수화물","단백질","지방"})

# NUTR_CONT1':'열량','NUTR_CONT2':'탄수화물', 'NUTR_CONT3':'단백질','NUTR_CONT4':'지방'

from tqdm.notebook import tqdm

for i in tqdm(range(2900000,3000000)):
  nr1=0
  nr2=0
  nr3=0
  nr4=0
  ri=rice.index(all_m[i][0])
  so=soup.index(all_m[i][1])
  si=side.index(all_m[i][2])
  nr1=int(i_rice[ri]["열량"])+int(i_soup[so]["열량"])+int(i_side[si]["열량"])
  nr2=int(i_rice[ri]["탄수화물"])+int(i_soup[so]["탄수화물"])+int(i_side[si]["탄수화물"])
  nr3=int(i_rice[ri]["단백질"])+int(i_soup[so]["단백질"])+int(i_side[si]["단백질"])
  nr4=int(i_rice[ri]["지방"])+int(i_soup[so]["지방"])+int(i_side[si]["지방"])
  combi={"음식":all_m[i],"열량":nr1,"탄수화물":nr2,"단백질":nr3,"지방":nr4}   
  food_combi=food_combi.append(combi,ignore_index=True)
food_combi=food_combi[["음식","열량","탄수화물","단백질","지방"]] 

dataframe=pd.DataFrame(food_combi)

dataframe.to_csv("/content/gdrive/MyDrive/캡스톤/coco/식품영양성분/영양성분표_밥국반찬SET_3000000.csv",index=False, header=True)
# Out:
#   0%|          | 0/100000 [00:00<?, ?it/s]

# %%
food_combi=pd.DataFrame(columns={"음식","열량","탄수화물","단백질","지방"})

# NUTR_CONT1':'열량','NUTR_CONT2':'탄수화물', 'NUTR_CONT3':'단백질','NUTR_CONT4':'지방'

from tqdm.notebook import tqdm

for i in tqdm(range(3000000,3100000)):
  nr1=0
  nr2=0
  nr3=0
  nr4=0
  ri=rice.index(all_m[i][0])
  so=soup.index(all_m[i][1])
  si=side.index(all_m[i][2])
  nr1=int(i_rice[ri]["열량"])+int(i_soup[so]["열량"])+int(i_side[si]["열량"])
  nr2=int(i_rice[ri]["탄수화물"])+int(i_soup[so]["탄수화물"])+int(i_side[si]["탄수화물"])
  nr3=int(i_rice[ri]["단백질"])+int(i_soup[so]["단백질"])+int(i_side[si]["단백질"])
  nr4=int(i_rice[ri]["지방"])+int(i_soup[so]["지방"])+int(i_side[si]["지방"])
  combi={"음식":all_m[i],"열량":nr1,"탄수화물":nr2,"단백질":nr3,"지방":nr4}   
  food_combi=food_combi.append(combi,ignore_index=True)
food_combi=food_combi[["음식","열량","탄수화물","단백질","지방"]] 

dataframe=pd.DataFrame(food_combi)

dataframe.to_csv("/content/gdrive/MyDrive/캡스톤/coco/식품영양성분/영양성분표_밥국반찬SET_3100000.csv",index=False, header=True)
# Out:
#   0%|          | 0/100000 [00:00<?, ?it/s]

# %%
food_combi=pd.DataFrame(columns={"음식","열량","탄수화물","단백질","지방"})

# NUTR_CONT1':'열량','NUTR_CONT2':'탄수화물', 'NUTR_CONT3':'단백질','NUTR_CONT4':'지방'

from tqdm.notebook import tqdm

for i in tqdm(range(3700000,3800000)):
  nr1=0
  nr2=0
  nr3=0
  nr4=0
  ri=rice.index(all_m[i][0])
  so=soup.index(all_m[i][1])
  si=side.index(all_m[i][2])
  nr1=int(i_rice[ri]["열량"])+int(i_soup[so]["열량"])+int(i_side[si]["열량"])
  nr2=int(i_rice[ri]["탄수화물"])+int(i_soup[so]["탄수화물"])+int(i_side[si]["탄수화물"])
  nr3=int(i_rice[ri]["단백질"])+int(i_soup[so]["단백질"])+int(i_side[si]["단백질"])
  nr4=int(i_rice[ri]["지방"])+int(i_soup[so]["지방"])+int(i_side[si]["지방"])
  combi={"음식":all_m[i],"열량":nr1,"탄수화물":nr2,"단백질":nr3,"지방":nr4}   
  food_combi=food_combi.append(combi,ignore_index=True)
food_combi=food_combi[["음식","열량","탄수화물","단백질","지방"]] 

dataframe=pd.DataFrame(food_combi)

dataframe.to_csv("/content/gdrive/MyDrive/캡스톤/coco/식품영양성분/영양성분표_밥국반찬SET_3800000.csv",index=False, header=True)
# Out:
#   0%|          | 0/100000 [00:00<?, ?it/s]

# %% [markdown]
# ### ~4300000 합치기 => df_4300000

# %%
a1=pd.read_csv("/content/gdrive/MyDrive/캡스톤/coco/식품영양성분/영양성분표_밥국반찬SET_10000.csv")
a2=pd.read_csv("/content/gdrive/MyDrive/캡스톤/coco/식품영양성분/영양성분표_밥국반찬SET_100000.csv")
b2=pd.read_csv("/content/gdrive/MyDrive/캡스톤/coco/식품영양성분/영양성분표_밥국반찬SET_200000.csv")
b3=pd.read_csv("/content/gdrive/MyDrive/캡스톤/coco/식품영양성분/영양성분표_밥국반찬SET_300000.csv")
b4=pd.read_csv("/content/gdrive/MyDrive/캡스톤/coco/식품영양성분/영양성분표_밥국반찬SET_400000.csv")
b5=pd.read_csv("/content/gdrive/MyDrive/캡스톤/coco/식품영양성분/영양성분표_밥국반찬SET_500000.csv")
b6=pd.read_csv("/content/gdrive/MyDrive/캡스톤/coco/식품영양성분/영양성분표_밥국반찬SET_600000.csv")
b7=pd.read_csv("/content/gdrive/MyDrive/캡스톤/coco/식품영양성분/영양성분표_밥국반찬SET_700000.csv")
b8=pd.read_csv("/content/gdrive/MyDrive/캡스톤/coco/식품영양성분/영양성분표_밥국반찬SET_800000.csv")
b9=pd.read_csv("/content/gdrive/MyDrive/캡스톤/coco/식품영양성분/영양성분표_밥국반찬SET_900000.csv")
a3=pd.read_csv("/content/gdrive/MyDrive/캡스톤/coco/식품영양성분/영양성분표_밥국반찬SET_1000000.csv")
a4=pd.read_csv("/content/gdrive/MyDrive/캡스톤/coco/식품영양성분/영양성분표_밥국반찬SET_1100000.csv")
a5=pd.read_csv("/content/gdrive/MyDrive/캡스톤/coco/식품영양성분/영양성분표_밥국반찬SET_1200000.csv")
a6=pd.read_csv("/content/gdrive/MyDrive/캡스톤/coco/식품영양성분/영양성분표_밥국반찬SET_1300000.csv")
a7=pd.read_csv("/content/gdrive/MyDrive/캡스톤/coco/식품영양성분/영양성분표_밥국반찬SET_1400000.csv")
a8=pd.read_csv("/content/gdrive/MyDrive/캡스톤/coco/식품영양성분/영양성분표_밥국반찬SET_1500000.csv")
a9=pd.read_csv("/content/gdrive/MyDrive/캡스톤/coco/식품영양성분/영양성분표_밥국반찬SET_1600000.csv")
a10=pd.read_csv("/content/gdrive/MyDrive/캡스톤/coco/식품영양성분/영양성분표_밥국반찬SET_1700000.csv")
a11=pd.read_csv("/content/gdrive/MyDrive/캡스톤/coco/식품영양성분/영양성분표_밥국반찬SET_1800000.csv")
a12=pd.read_csv("/content/gdrive/MyDrive/캡스톤/coco/식품영양성분/영양성분표_밥국반찬SET_1900000.csv")
a13=pd.read_csv("/content/gdrive/MyDrive/캡스톤/coco/식품영양성분/영양성분표_밥국반찬SET_2000000.csv")
a14=pd.read_csv("/content/gdrive/MyDrive/캡스톤/coco/식품영양성분/영양성분표_밥국반찬SET_2100000.csv")
a15=pd.read_csv("/content/gdrive/MyDrive/캡스톤/coco/식품영양성분/영양성분표_밥국반찬SET_2200000.csv")
a16=pd.read_csv("/content/gdrive/MyDrive/캡스톤/coco/식품영양성분/영양성분표_밥국반찬SET_2300000.csv")
a17=pd.read_csv("/content/gdrive/MyDrive/캡스톤/coco/식품영양성분/영양성분표_밥국반찬SET_2400000.csv")
a18=pd.read_csv("/content/gdrive/MyDrive/캡스톤/coco/식품영양성분/영양성분표_밥국반찬SET_2500000.csv")
a19=pd.read_csv("/content/gdrive/MyDrive/캡스톤/coco/식품영양성분/영양성분표_밥국반찬SET_2600000.csv")
a20=pd.read_csv("/content/gdrive/MyDrive/캡스톤/coco/식품영양성분/영양성분표_밥국반찬SET_2700000.csv")
a21=pd.read_csv("/content/gdrive/MyDrive/캡스톤/coco/식품영양성분/영양성분표_밥국반찬SET_2800000.csv")
a22=pd.read_csv("/content/gdrive/MyDrive/캡스톤/coco/식품영양성분/영양성분표_밥국반찬SET_2900000.csv")
a23=pd.read_csv("/content/gdrive/MyDrive/캡스톤/coco/식품영양성분/영양성분표_밥국반찬SET_3000000.csv")
a24=pd.read_csv("/content/gdrive/MyDrive/캡스톤/coco/식품영양성분/영양성분표_밥국반찬SET_3100000.csv")
a25=pd.read_csv("/content/gdrive/MyDrive/캡스톤/coco/식품영양성분/영양성분표_밥국반찬SET_3200000.csv")
a26=pd.read_csv("/content/gdrive/MyDrive/캡스톤/coco/식품영양성분/영양성분표_밥국반찬SET_3300000.csv")
a27=pd.read_csv("/content/gdrive/MyDrive/캡스톤/coco/식품영양성분/영양성분표_밥국반찬SET_3400000.csv")
a28=pd.read_csv("/content/gdrive/MyDrive/캡스톤/coco/식품영양성분/영양성분표_밥국반찬SET_3500000.csv")
a29=pd.read_csv("/content/gdrive/MyDrive/캡스톤/coco/식품영양성분/영양성분표_밥국반찬SET_3600000.csv")
a30=pd.read_csv("/content/gdrive/MyDrive/캡스톤/coco/식품영양성분/영양성분표_밥국반찬SET_3700000.csv")
a31=pd.read_csv("/content/gdrive/MyDrive/캡스톤/coco/식품영양성분/영양성분표_밥국반찬SET_3800000.csv")
a32=pd.read_csv("/content/gdrive/MyDrive/캡스톤/coco/식품영양성분/영양성분표_밥국반찬SET_3900000.csv")
a33=pd.read_csv("/content/gdrive/MyDrive/캡스톤/coco/식품영양성분/영양성분표_밥국반찬SET_4000000.csv")
a34=pd.read_csv("/content/gdrive/MyDrive/캡스톤/coco/식품영양성분/영양성분표_밥국반찬SET_4300000.csv")

# %%
a1.head()
# Out:
#                        음식    열량  탄수화물  단백질  지방
# 0  ('굴국밥', '곰치국', '꿩불고기')  1470   150  129  36
# 1   ('굴국밥', '곰치국', '닭갈비')  1697   155  141  53
# 2   ('굴국밥', '곰치국', '닭꼬치')  1278   124  107  36

# %%
s=[a1]
i=3
s.append('a'+str(i))
print(s)
# Out:
# [                       음식    열량  탄수화물  단백질  지방
# 0  ('굴국밥', '곰치국', '꿩불고기')  1470   150  129  36
# 1   ('굴국밥', '곰치국', '닭갈비')  1697   155  141  53
# 2   ('굴국밥', '곰치국', '닭꼬치')  1278   124  107  36, 'a3']

# %%
#df_list=['a1','a2','b2','b3','b4','b5','b6','b7','b8','b9']
df_list=[a1,a2,b2,b3,b4,b5,b6,b7,b8,b9,a3,a4,a5,a6,a7,a8,a9,a10,a11,a12,a13,a14,a15,a16,a17,a18,a19,a20,a21,a22,a23,a24,a25,a26,a27,a28,a29,a30,a31,a32,a33,a34]

# %%
print(df_list)
# Out:
# [                       음식    열량  탄수화물  단백질  지방
# 0  ('굴국밥', '곰치국', '꿩불고기')  1470   150  129  36
# 1   ('굴국밥', '곰치국', '닭갈비')  1697   155  141  53
# 2   ('굴국밥', '곰치국', '닭꼬치')  1278   124  107  36,                               음식    열량  탄수화물  단백질  지방
# 0         ('굴국밥', '곰치국', '꿩불고기')  1470   150  129  36
# 1          ('굴국밥', '곰치국', '닭갈비')  1697   155  141  53
# 2          ('굴국밥', '곰치국', '닭꼬치')  1278   124  107  36
# 3         ('굴국밥', '곰치국', '더덕구이')  1286   142   99  33
# 4         ('굴국밥', '곰치국', '도미구이')  1499   113  157  44
# ...                          ...   ...   ...  ...  ..
# 99995  ('간짜장', '쑥된장국', '돼지등갈비찜')  1845   197   98  72
# 99996  ('간짜장', '쑥된장국', '돼지머리고기')  1534   143   68  75
# 99997   ('간짜장', '쑥된장국', '매운갈비찜')  1401   163   87  42
# 99998    ('간짜장', '쑥된장국', '문어숙회')   950   140   40  23
# 99999     ('간짜장', '쑥된장국', '민어찜')  1020   140   47  28
#
# [100000 rows x 5 columns],                                 음식    열량  탄수화물  단백질  지방
# ...

# %%
len(df_list)
# Out:
# 42

# %%
import pandas as pd
df_4300000= pd.concat(df_list, ignore_index=True)

# %%
len(df_4300000)
# Out:
# 4300003

# %%
df_4300000
# Out:
#                                     음식    열량  탄수화물  단백질   지방
# 0               ('굴국밥', '곰치국', '꿩불고기')  1470   150  129   36
# 1                ('굴국밥', '곰치국', '닭갈비')  1697   155  141   53
# 2                ('굴국밥', '곰치국', '닭꼬치')  1278   124  107   36
# 3               ('굴국밥', '곰치국', '꿩불고기')  1470   150  129   36
# 4                ('굴국밥', '곰치국', '닭갈비')  1697   155  141   53
# ...                                ...   ...   ...  ...  ...
# 4299998    ('비빔냉면', '사골만두국', '런천미트구이')  1589   133   82   79
# 4299999     ('비빔냉면', '사골만두국', '뱅어포구이')  1367   145   78   50
# 4300000      ('비빔냉면', '사골만두국', '버섯구이')  1146   131   58   41
# 4300001  ('비빔냉면', '사골만두국', '삼겹살고추장구이')  1910   153   82  105
# 4300002     ('비빔냉면', '사골만두국', '삼겹살구이')  2038   128   99  123
#
# [4300003 rows x 5 columns]

# %% [markdown]
# # ~7,000,000 (7백만개)

# %%
import pandas as pd
from google.colab import drive 
drive.mount('/content/gdrive/')
# Out:
# Mounted at /content/gdrive/

# %%
food_combi=pd.DataFrame(columns={"음식","열량","탄수화물","단백질","지방"})

# NUTR_CONT1':'열량','NUTR_CONT2':'탄수화물', 'NUTR_CONT3':'단백질','NUTR_CONT4':'지방'

from tqdm.notebook import tqdm

for i in tqdm(range(7000000,7300000)):
  nr1=0
  nr2=0
  nr3=0
  nr4=0
  ri=rice.index(all_m[i][0])
  so=soup.index(all_m[i][1])
  si=side.index(all_m[i][2])
  nr1=int(i_rice[ri]["열량"])+int(i_soup[so]["열량"])+int(i_side[si]["열량"])
  nr2=int(i_rice[ri]["탄수화물"])+int(i_soup[so]["탄수화물"])+int(i_side[si]["탄수화물"])
  nr3=int(i_rice[ri]["단백질"])+int(i_soup[so]["단백질"])+int(i_side[si]["단백질"])
  nr4=int(i_rice[ri]["지방"])+int(i_soup[so]["지방"])+int(i_side[si]["지방"])
  combi={"음식":all_m[i],"열량":nr1,"탄수화물":nr2,"단백질":nr3,"지방":nr4}   
  food_combi=food_combi.append(combi,ignore_index=True)
food_combi=food_combi[["음식","열량","탄수화물","단백질","지방"]] 

dataframe=pd.DataFrame(food_combi)

dataframe.to_csv("/content/gdrive/MyDrive/영양성분표/영양성분표_밥국반찬SET_7300000.csv",index=False, header=True)
# Out:
#   0%|          | 0/300000 [00:00<?, ?it/s]

# %%
food_combi=pd.DataFrame(columns={"음식","열량","탄수화물","단백질","지방"})

# NUTR_CONT1':'열량','NUTR_CONT2':'탄수화물', 'NUTR_CONT3':'단백질','NUTR_CONT4':'지방'

from tqdm.notebook import tqdm

for i in tqdm(range(7300000,7600000)):
  nr1=0
  nr2=0
  nr3=0
  nr4=0
  ri=rice.index(all_m[i][0])
  so=soup.index(all_m[i][1])
  si=side.index(all_m[i][2])
  nr1=int(i_rice[ri]["열량"])+int(i_soup[so]["열량"])+int(i_side[si]["열량"])
  nr2=int(i_rice[ri]["탄수화물"])+int(i_soup[so]["탄수화물"])+int(i_side[si]["탄수화물"])
  nr3=int(i_rice[ri]["단백질"])+int(i_soup[so]["단백질"])+int(i_side[si]["단백질"])
  nr4=int(i_rice[ri]["지방"])+int(i_soup[so]["지방"])+int(i_side[si]["지방"])
  combi={"음식":all_m[i],"열량":nr1,"탄수화물":nr2,"단백질":nr3,"지방":nr4}   
  food_combi=food_combi.append(combi,ignore_index=True)
food_combi=food_combi[["음식","열량","탄수화물","단백질","지방"]] 

dataframe=pd.DataFrame(food_combi)

dataframe.to_csv("/content/gdrive/MyDrive/영양성분표/영양성분표_밥국반찬SET_7600000.csv",index=False, header=True)
# Out:
#   0%|          | 0/300000 [00:00<?, ?it/s]

# %%
food_combi=pd.DataFrame(columns={"음식","열량","탄수화물","단백질","지방"})

# NUTR_CONT1':'열량','NUTR_CONT2':'탄수화물', 'NUTR_CONT3':'단백질','NUTR_CONT4':'지방'

from tqdm.notebook import tqdm

for i in tqdm(range(7600000,8000000)):
  nr1=0
  nr2=0
  nr3=0
  nr4=0
  ri=rice.index(all_m[i][0])
  so=soup.index(all_m[i][1])
  si=side.index(all_m[i][2])
  nr1=int(i_rice[ri]["열량"])+int(i_soup[so]["열량"])+int(i_side[si]["열량"])
  nr2=int(i_rice[ri]["탄수화물"])+int(i_soup[so]["탄수화물"])+int(i_side[si]["탄수화물"])
  nr3=int(i_rice[ri]["단백질"])+int(i_soup[so]["단백질"])+int(i_side[si]["단백질"])
  nr4=int(i_rice[ri]["지방"])+int(i_soup[so]["지방"])+int(i_side[si]["지방"])
  combi={"음식":all_m[i],"열량":nr1,"탄수화물":nr2,"단백질":nr3,"지방":nr4}   
  food_combi=food_combi.append(combi,ignore_index=True)
food_combi=food_combi[["음식","열량","탄수화물","단백질","지방"]] 

dataframe=pd.DataFrame(food_combi)

dataframe.to_csv("/content/gdrive/MyDrive/영양성분표/영양성분표_밥국반찬SET_8000000.csv",index=False, header=True)
# Out:
#   0%|          | 0/400000 [00:00<?, ?it/s]

# %%
food_combi=pd.DataFrame(columns={"음식","열량","탄수화물","단백질","지방"})

# NUTR_CONT1':'열량','NUTR_CONT2':'탄수화물', 'NUTR_CONT3':'단백질','NUTR_CONT4':'지방'

from tqdm.notebook import tqdm

for i in tqdm(range(8000000,8300000)):
  nr1=0
  nr2=0
  nr3=0
  nr4=0
  ri=rice.index(all_m[i][0])
  so=soup.index(all_m[i][1])
  si=side.index(all_m[i][2])
  nr1=int(i_rice[ri]["열량"])+int(i_soup[so]["열량"])+int(i_side[si]["열량"])
  nr2=int(i_rice[ri]["탄수화물"])+int(i_soup[so]["탄수화물"])+int(i_side[si]["탄수화물"])
  nr3=int(i_rice[ri]["단백질"])+int(i_soup[so]["단백질"])+int(i_side[si]["단백질"])
  nr4=int(i_rice[ri]["지방"])+int(i_soup[so]["지방"])+int(i_side[si]["지방"])
  combi={"음식":all_m[i],"열량":nr1,"탄수화물":nr2,"단백질":nr3,"지방":nr4}   
  food_combi=food_combi.append(combi,ignore_index=True)
food_combi=food_combi[["음식","열량","탄수화물","단백질","지방"]] 

dataframe=pd.DataFrame(food_combi)

dataframe.to_csv("/content/gdrive/MyDrive/영양성분표/영양성분표_밥국반찬SET_8300000.csv",index=False, header=True)
# Out:
#   0%|          | 0/300000 [00:00<?, ?it/s]

# %%
food_combi=pd.DataFrame(columns={"음식","열량","탄수화물","단백질","지방"})

# NUTR_CONT1':'열량','NUTR_CONT2':'탄수화물', 'NUTR_CONT3':'단백질','NUTR_CONT4':'지방'

from tqdm.notebook import tqdm

for i in tqdm(range(8300000,8600000)):
  nr1=0
  nr2=0
  nr3=0
  nr4=0
  ri=rice.index(all_m[i][0])
  so=soup.index(all_m[i][1])
  si=side.index(all_m[i][2])
  nr1=int(i_rice[ri]["열량"])+int(i_soup[so]["열량"])+int(i_side[si]["열량"])
  nr2=int(i_rice[ri]["탄수화물"])+int(i_soup[so]["탄수화물"])+int(i_side[si]["탄수화물"])
  nr3=int(i_rice[ri]["단백질"])+int(i_soup[so]["단백질"])+int(i_side[si]["단백질"])
  nr4=int(i_rice[ri]["지방"])+int(i_soup[so]["지방"])+int(i_side[si]["지방"])
  combi={"음식":all_m[i],"열량":nr1,"탄수화물":nr2,"단백질":nr3,"지방":nr4}   
  food_combi=food_combi.append(combi,ignore_index=True)
food_combi=food_combi[["음식","열량","탄수화물","단백질","지방"]] 

dataframe=pd.DataFrame(food_combi)

dataframe.to_csv("/content/gdrive/MyDrive/영양성분표/영양성분표_밥국반찬SET_8600000.csv",index=False, header=True)
# Out:
#   0%|          | 0/300000 [00:00<?, ?it/s]

# %%
food_combi=pd.DataFrame(columns={"음식","열량","탄수화물","단백질","지방"})

# NUTR_CONT1':'열량','NUTR_CONT2':'탄수화물', 'NUTR_CONT3':'단백질','NUTR_CONT4':'지방'

from tqdm.notebook import tqdm

for i in tqdm(range(8600000,9154456)):
  nr1=0
  nr2=0
  nr3=0
  nr4=0
  ri=rice.index(all_m[i][0])
  so=soup.index(all_m[i][1])
  si=side.index(all_m[i][2])
  nr1=int(i_rice[ri]["열량"])+int(i_soup[so]["열량"])+int(i_side[si]["열량"])
  nr2=int(i_rice[ri]["탄수화물"])+int(i_soup[so]["탄수화물"])+int(i_side[si]["탄수화물"])
  nr3=int(i_rice[ri]["단백질"])+int(i_soup[so]["단백질"])+int(i_side[si]["단백질"])
  nr4=int(i_rice[ri]["지방"])+int(i_soup[so]["지방"])+int(i_side[si]["지방"])
  combi={"음식":all_m[i],"열량":nr1,"탄수화물":nr2,"단백질":nr3,"지방":nr4}   
  food_combi=food_combi.append(combi,ignore_index=True)
food_combi=food_combi[["음식","열량","탄수화물","단백질","지방"]] 

dataframe=pd.DataFrame(food_combi)

dataframe.to_csv("/content/gdrive/MyDrive/영양성분표/영양성분표_밥국반찬SET_9154456.csv",index=False, header=True)
# Out:
#   0%|          | 0/554456 [00:00<?, ?it/s]

# %%
df_7000000 = pd.read_csv("/content/gdrive/MyDrive/영양성분표/merge_set_7000000.csv")
a42=pd.read_csv("/content/gdrive/MyDrive/영양성분표/영양성분표_밥국반찬SET_7300000.csv")
a43=pd.read_csv("/content/gdrive/MyDrive/영양성분표/영양성분표_밥국반찬SET_7600000.csv")
a44=pd.read_csv("/content/gdrive/MyDrive/영양성분표/영양성분표_밥국반찬SET_8000000.csv")
a45=pd.read_csv("/content/gdrive/MyDrive/영양성분표/영양성분표_밥국반찬SET_8300000.csv")
a46=pd.read_csv("/content/gdrive/MyDrive/영양성분표/영양성분표_밥국반찬SET_8600000.csv")
a47=pd.read_csv("/content/gdrive/MyDrive/영양성분표/영양성분표_밥국반찬SET_9154456.csv")

df_list=[df_7000000,a42,a43,a44,a45,a46,a47]
df_8000000= pd.concat(df_list, ignore_index=True)

df_8000000.to_csv("/content/gdrive/MyDrive/영양성분표/merge_set_9154456.csv",index=False, header=True)

# %%
print(df_8000000.value_counts())
# Out:
# 음식                          열량    탄수화물  단백질  지방
# ('짜장면', '조갯국', '표고버섯구이')    937   147   28   23    2
# ('짜장면', '새우미역국', '계적')      1347  140   80   51    2
# ('짜장면', '새우미역국', '게국지')     1274  171   67   33    2
# ('짜장면', '새우미역국', '건취나물무침')  903   143   24   23    2
# ('짜장면', '새우미역국', '건새우볶음')   919   141   31   23    2
#                                                   ..
# ('삼선볶음밥', '황태해장국', '회무침')   1070  111   70   36    1
# ('삼선볶음밥', '황태해장국', '황태구이')  1304  116   97   47    1
# ('삼선볶음밥', '황태해장국', '화양적')   1139  111   63   46    1
# ('삼선볶음밥', '황태해장국', '홍합산적')  1023  100   67   36    1
# ('흑임자죽', '황태해장국', '훈제오리')   1223  31    71   88    1
# Length: 9089988, dtype: int64

# %%
len(df_8000000)
# Out:
# 9154459

# %%
D = df_8000000.drop_duplicates()
print(D.value_counts())
# Out:
# 음식                           열량    탄수화물  단백질  지방
# ('간짜장', '갈낙탕', '가오리찜')       1289  134   100  36    1
# ('쟁반국수', '갈낙탕', '가자미구이')     1041  58    102  42    1
# ('장어초밥', '황태해장국', '황태구이')    1104  111   87   31    1
# ('장어초밥', '황태해장국', '회무침')     870   106   60   20    1
# ('장어초밥', '황태해장국', '후라이드치킨')  1197  106   75   49    1
#                                                    ..
# ('삼선볶음밥', '황태해장국', '홍합산적')   1023  100   67   36    1
# ('삼선볶음밥', '황태해장국', '홍어찜')    1069  91    97   33    1
# ('삼선볶음밥', '황태해장국', '홍어적')    956   90    73   32    1
# ('삼선볶음밥', '황태해장국', '홍어무침')   1065  115   67   34    1
# ('흑임자죽', '황태해장국', '훈제오리')    1223  31    71   88    1
# Length: 9089988, dtype: int64

# %%
len(D)
# Out:
# 9089988

# %%
D.to_csv("/content/gdrive/MyDrive/영양성분표/merge_ALL.csv",index=False,header=True)

# %%
D
# Out:
#                                     음식    열량  탄수화물  단백질  지방
# 0               ('굴국밥', '곰치국', '꿩불고기')  1470   150  129  36
# 1                ('굴국밥', '곰치국', '닭갈비')  1697   155  141  53
# 2                ('굴국밥', '곰치국', '닭꼬치')  1278   124  107  36
# 6               ('굴국밥', '곰치국', '더덕구이')  1286   142   99  33
# 7               ('굴국밥', '곰치국', '도미구이')  1499   113  157  44
# ...                                ...   ...   ...  ...  ..
# 9154454   ('흑임자죽', '호박고추장찌개', '오징어튀김')   865    63   27  52
# 9154455    ('흑임자죽', '호박고추장찌개', '채소튀김')   764    66   12  47
# 9154456    ('흑임자죽', '호박고추장찌개', '치킨너겟')   828    44   31  55
# 9154457     ('흑임자죽', '호박고추장찌개', '탕수육')   718    54   36  36
# 9154458  ('흑임자죽', '호박고추장찌개', '후라이드치킨')   890    51   44  53
#
# [9089988 rows x 5 columns]

# %% [markdown]
# # 다이어트 식단

# %%
import pandas as pd
data = pd.read_excel('/content/gdrive/MyDrive/영양성분표/다이어트.xlsx')

# %%
data.to_csv("/content/gdrive/MyDrive/영양성분표/다이어트식단.csv")

# %%
data.head()
# Out:
#                  음식 분류  열량(kcal)  탄수화물(g)  단백질(g)  지방(g)  탄수화물(kcal)  \
# 0           쌀밥(반공기)  밥       310    67.32    5.61   0.85      269.28
# 1        도토리묵밥(반공기)  밥       338    61.00   12.25   5.00      244.00
# 2         곤드레밥(반공기)  밥       359    83.00    6.00   0.00      332.00
# 3  곤약밥(쌀5:곤약5)(반공기)  밥       160    38.90    3.40   0.10      155.60
# 4          귀리밥(반공기)  밥       285    63.00    6.00   1.00      252.00
#
#    단백질(kcal)  지방(kcal)  열량(kcal)_밥  탄수화물(kcal)_밥  단백질(kcal)_밥  지방(kcal)_밥
# 0      22.44      7.65       155.0        134.64        11.22       3.825
# 1      49.00     45.00       169.0        122.00        24.50      22.500
# 2      24.00      0.00       179.5        166.00        12.00       0.000
# 3      13.60      0.90        80.0         77.80         6.80       0.450
# 4      24.00      9.00       142.5        126.00        12.00       4.500

# %%
data.columns
# Out:
# Index(['음식', '분류', '열량(kcal)', '탄수화물(g)', '단백질(g)', '지방(g)', '탄수화물(kcal)',
#        '단백질(kcal)', '지방(kcal)', '열량(kcal)_밥', '탄수화물(kcal)_밥', '단백질(kcal)_밥',
#        '지방(kcal)_밥'],
#       dtype='object')

# %%
data=data.drop(['탄수화물(g)', '단백질(g)', '지방(g)'],axis=1)

# %%
data.head()
# Out:
#                  음식 분류  열량(kcal)  탄수화물(kcal)  단백질(kcal)  지방(kcal)  열량(kcal)_밥  \
# 0           쌀밥(반공기)  밥       310      269.28      22.44      7.65       155.0
# 1        도토리묵밥(반공기)  밥       338      244.00      49.00     45.00       169.0
# 2         곤드레밥(반공기)  밥       359      332.00      24.00      0.00       179.5
# 3  곤약밥(쌀5:곤약5)(반공기)  밥       160      155.60      13.60      0.90        80.0
# 4          귀리밥(반공기)  밥       285      252.00      24.00      9.00       142.5
#
#    탄수화물(kcal)_밥  단백질(kcal)_밥  지방(kcal)_밥
# 0        134.64        11.22       3.825
# 1        122.00        24.50      22.500
# 2        166.00        12.00       0.000
# 3         77.80         6.80       0.450
# 4        126.00        12.00       4.500

# %%
r_data=data[:10]
r_data=r_data.drop(['열량(kcal)','탄수화물(kcal)','단백질(kcal)', '지방(kcal)'],axis=1)

# %%
r_data.columns
# Out:
# Index(['음식', '분류', '열량(kcal)_밥', '탄수화물(kcal)_밥', '단백질(kcal)_밥', '지방(kcal)_밥'], dtype='object')

# %%
r_data=r_data.rename(columns={'열량(kcal)_밥' : '열량(kcal)', '탄수화물(kcal)_밥': '탄수화물(kcal)', '단백질(kcal)_밥':'단백질(kcal)', '지방(kcal)_밥':'지방(kcal)'})

# %%
data=data.drop(['열량(kcal)_밥','탄수화물(kcal)_밥','단백질(kcal)_밥', '지방(kcal)_밥'],axis=1)

# %%
data=data[10:]

# %%
r_data
# Out:
#                   음식 분류  열량(kcal)  탄수화물(kcal)  단백질(kcal)  지방(kcal)
# 0            쌀밥(반공기)  밥     155.0      134.64      11.22     3.825
# 1         도토리묵밥(반공기)  밥     169.0      122.00      24.50    22.500
# 2          곤드레밥(반공기)  밥     179.5      166.00      12.00     0.000
# 3   곤약밥(쌀5:곤약5)(반공기)  밥      80.0       77.80       6.80     0.450
# 4           귀리밥(반공기)  밥     142.5      126.00      12.00     4.500
# 5           현미밥(반공기)  밥     160.5      137.90      12.60     6.885
# 6          강낭콩밥(반공기)  밥     175.0      154.00      14.50     0.900
# 7          검은콩밥(반공기)  밥     132.0      114.76      11.30     2.070
# 8          고구마밥(반공기)  밥     156.0      150.56      10.24     0.720
# 9  콩나물밥(양념장 포함)(반공기)  밥     198.0      142.44      28.40    13.455

# %%
data=pd.concat([r_data,data])

# %%
data
# Out:
#                    음식   분류  열량(kcal)  탄수화물(kcal)  단백질(kcal)  지방(kcal)
# 0             쌀밥(반공기)    밥     155.0      134.64      11.22     3.825
# 1          도토리묵밥(반공기)    밥     169.0      122.00      24.50    22.500
# 2           곤드레밥(반공기)    밥     179.5      166.00      12.00     0.000
# 3    곤약밥(쌀5:곤약5)(반공기)    밥      80.0       77.80       6.80     0.450
# 4            귀리밥(반공기)    밥     142.5      126.00      12.00     4.500
# 5            현미밥(반공기)    밥     160.5      137.90      12.60     6.885
# 6           강낭콩밥(반공기)    밥     175.0      154.00      14.50     0.900
# 7           검은콩밥(반공기)    밥     132.0      114.76      11.30     2.070
# 8           고구마밥(반공기)    밥     156.0      150.56      10.24     0.720
# 9   콩나물밥(양념장 포함)(반공기)    밥     198.0      142.44      28.40    13.455
# 10               쇠고기국    국      78.0       27.52      32.88    24.390
# 11               시래기국    국      53.0       24.44      18.88    15.930
# ...

# %%
#list(combinations(nums,3))

rice=[]
i_rice=[]
soup=[]
i_soup=[]
side=[]
i_side=[]

for i in range(len(data['분류'])):
  if data['분류'][i]=="반찬":
    side.append(data['음식'][i])
    i_side.append(data.iloc[i])
  elif data['분류'][i]=="국":
    soup.append(data['음식'][i])
    i_soup.append(data.iloc[i])
  elif data['분류'][i]=="밥":
    rice.append(data['음식'][i])
    i_rice.append(data.iloc[i])

print(len(rice))
print(len(soup))
print(len(side))
# Out:
# 10
# 11
# 20

# %%
rice
# Out:
# ['쌀밥(반공기)',
#  '도토리묵밥(반공기)',
#  '곤드레밥(반공기)',
#  '곤약밥(쌀5:곤약5)(반공기)',
#  '귀리밥(반공기)',
#  '현미밥(반공기)',
#  '강낭콩밥(반공기)',
#  '검은콩밥(반공기)',
#  '고구마밥(반공기)',
#  '콩나물밥(양념장 포함)(반공기)']

# %%
from itertools import product

meal=[rice,soup,side]

all_m=list(product(*meal))

# %%
len(all_m)
# Out:
# 2200

# %%
all_m
# Out:
# [('쌀밥(반공기)', '쇠고기국', '콩나물무침'),
#  ('쌀밥(반공기)', '쇠고기국', '고사리나물'),
#  ('쌀밥(반공기)', '쇠고기국', '버섯볶음'),
#  ('쌀밥(반공기)', '쇠고기국', '진미채볶음'),
#  ('쌀밥(반공기)', '쇠고기국', '낚지볶음'),
#  ('쌀밥(반공기)', '쇠고기국', '김치참치볶음'),
#  ('쌀밥(반공기)', '쇠고기국', '갈치구이'),
#  ('쌀밥(반공기)', '쇠고기국', '조기구이'),
#  ('쌀밥(반공기)', '쇠고기국', '잔멸치볶음'),
#  ('쌀밥(반공기)', '쇠고기국', '감자채볶음'),
#  ('쌀밥(반공기)', '쇠고기국', '애호박볶음'),
#  ('쌀밥(반공기)', '쇠고기국', '골뱅이무침'),
#  ('쌀밥(반공기)', '쇠고기국', '홍합무침'),
#  ('쌀밥(반공기)', '쇠고기국', '코다리찜'),
#  ('쌀밥(반공기)', '쇠고기국', '콩나물찜'),
#  ('쌀밥(반공기)', '쇠고기국', '훈제닭가슴살'),
#  ('쌀밥(반공기)', '쇠고기국', '계란프라이'),
#  ('쌀밥(반공기)', '쇠고기국', '계란찜'),
#  ('쌀밥(반공기)', '쇠고기국', '계란햄말이'),
#  ('쌀밥(반공기)', '쇠고기국', '쇠고기장조림'),
#  ('쌀밥(반공기)', '시래기국', '콩나물무침'),
#  ('쌀밥(반공기)', '시래기국', '고사리나물'),
#  ('쌀밥(반공기)', '시래기국', '버섯볶음'),
#  ('쌀밥(반공기)', '시래기국', '진미채볶음'),
#  ('쌀밥(반공기)', '시래기국', '낚지볶음'),
#  ('쌀밥(반공기)', '시래기국', '김치참치볶음'),
#  ('쌀밥(반공기)', '시래기국', '갈치구이'),
#  ('쌀밥(반공기)', '시래기국', '조기구이'),
#  ('쌀밥(반공기)', '시래기국', '잔멸치볶음'),
#  ('쌀밥(반공기)', '시래기국', '감자채볶음'),
# ...

# %%
food_combi=pd.DataFrame(columns={"음식","열량(kcal)","탄수화물(kcal)","단백질(kcal)","지방(kcal)"})

# NUTR_CONT1':'열량','NUTR_CONT2':'탄수화물', 'NUTR_CONT3':'단백질','NUTR_CONT4':'지방'

from tqdm.notebook import tqdm

for i in tqdm(range(0,len(all_m))):
  nr1=0
  nr2=0
  nr3=0
  nr4=0
  ri=rice.index(all_m[i][0])
  so=soup.index(all_m[i][1])
  si=side.index(all_m[i][2])
  nr1=int(i_rice[ri]["열량(kcal)"])+int(i_soup[so]["열량(kcal)"])+int(i_side[si]["열량(kcal)"])
  nr2=int(i_rice[ri]["탄수화물(kcal)"])+int(i_soup[so]["탄수화물(kcal)"])+int(i_side[si]["탄수화물(kcal)"])
  nr3=int(i_rice[ri]["단백질(kcal)"])+int(i_soup[so]["단백질(kcal)"])+int(i_side[si]["단백질(kcal)"])
  nr4=int(i_rice[ri]["지방(kcal)"])+int(i_soup[so]["지방(kcal)"])+int(i_side[si]["지방(kcal)"])
  combi={"음식":all_m[i],"열량(kcal)":nr1,"탄수화물(kcal)":nr2,"단백질(kcal)":nr3,"지방(kcal)":nr4}   
  food_combi=food_combi.append(combi,ignore_index=True)
food_combi=food_combi[["음식","열량(kcal)","탄수화물(kcal)","단백질(kcal)","지방(kcal)"]] 

dataframe=pd.DataFrame(food_combi)

# %%
dataframe.to_csv("/content/gdrive/MyDrive/영양성분표/다이어트식단_밥국반찬SET.csv",index=False, header=True)

# %%
dataframe.head()
# Out:
#                        음식 열량(kcal) 탄수화물(kcal) 단백질(kcal) 지방(kcal)
# 0  (쌀밥(반공기), 쇠고기국, 콩나물무침)      271        184        52       37
# 1  (쌀밥(반공기), 쇠고기국, 고사리나물)      283        175        51       54
# 2   (쌀밥(반공기), 쇠고기국, 버섯볶음)      331        203        55       88
# 3  (쌀밥(반공기), 쇠고기국, 진미채볶음)      372        244        80       45
# 4   (쌀밥(반공기), 쇠고기국, 낚지볶음)      420        247       102       67

# %%
import pandas as pd
data=pd.read_csv('/content/drive/MyDrive/영양성분표/다이어트식단_밥국반찬SET.csv')

# %%
data.head()
# Out:
#                              음식  열량(kcal)  탄수화물(kcal)  단백질(kcal)  지방(kcal)
# 0  ('쌀밥(반공기)', '쇠고기국', '콩나물무침')       271         184         52        37
# 1  ('쌀밥(반공기)', '쇠고기국', '고사리나물')       283         175         51        54
# 2   ('쌀밥(반공기)', '쇠고기국', '버섯볶음')       331         203         55        88
# 3  ('쌀밥(반공기)', '쇠고기국', '진미채볶음')       372         244         80        45
# 4   ('쌀밥(반공기)', '쇠고기국', '낚지볶음')       420         247        102        67

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import torch
import random

import torch.optim as optim
import torch.nn as nn
from sklearn.preprocessing import StandardScaler, RobustScaler

# %%
X = data.drop('음식', axis = 1)
Y = data.drop(['열량(kcal)','탄수화물(kcal)','단백질(kcal)','지방(kcal)'],axis=1)

# %%
X
# Out:
#       열량(kcal)  탄수화물(kcal)  단백질(kcal)  지방(kcal)
# 0          271         184         52        37
# 1          283         175         51        54
# 2          331         203         55        88
# 3          372         244         80        45
# 4          420         247        102        67
# ...        ...         ...        ...       ...
# 2195       374         173        147        54
# 2196       338         166         73        92
# 2197       449         182        118       145
# 2198       387         176         81       114
# 2199       381         190        120        68
#
# [2200 rows x 4 columns]

# %%
Y
# Out:
#                                            음식
# 0                ('쌀밥(반공기)', '쇠고기국', '콩나물무침')
# 1                ('쌀밥(반공기)', '쇠고기국', '고사리나물')
# 2                 ('쌀밥(반공기)', '쇠고기국', '버섯볶음')
# 3                ('쌀밥(반공기)', '쇠고기국', '진미채볶음')
# 4                 ('쌀밥(반공기)', '쇠고기국', '낚지볶음')
# ...                                       ...
# 2195  ('콩나물밥(양념장 포함)(반공기)', '우거지국', '훈제닭가슴살')
# 2196   ('콩나물밥(양념장 포함)(반공기)', '우거지국', '계란프라이')
# 2197     ('콩나물밥(양념장 포함)(반공기)', '우거지국', '계란찜')
# 2198   ('콩나물밥(양념장 포함)(반공기)', '우거지국', '계란햄말이')
# 2199  ('콩나물밥(양념장 포함)(반공기)', '우거지국', '쇠고기장조림')
#
# [2200 rows x 1 columns]

# %%
YY=data.drop(['열량(kcal)','탄수화물(kcal)','단백질(kcal)','지방(kcal)'],axis=1)

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
Y = le.fit_transform(Y['음식'])

# %%
label=Y

# %%
label
# Out:
# array([1676, 1665, 1669, ..., 1942, 1944, 1950])

# %%
label=pd.DataFrame([label])

# %%
label=label.transpose()

# %%
label
# Out:
#          0
# 0     1676
# 1     1665
# 2     1669
# 3     1674
# 4     1668
# ...    ...
# 2195  1959
# 2196  1943
# 2197  1942
# 2198  1944
# 2199  1950
#
# [2200 rows x 1 columns]

# %%
Y
# Out:
# array([1676, 1665, 1669, ..., 1942, 1944, 1950])

# %%
YY=pd.concat([YY,label],axis=1)
YY
# Out:
#                                            음식     0
# 0                ('쌀밥(반공기)', '쇠고기국', '콩나물무침')  1676
# 1                ('쌀밥(반공기)', '쇠고기국', '고사리나물')  1665
# 2                 ('쌀밥(반공기)', '쇠고기국', '버섯볶음')  1669
# 3                ('쌀밥(반공기)', '쇠고기국', '진미채볶음')  1674
# 4                 ('쌀밥(반공기)', '쇠고기국', '낚지볶음')  1668
# ...                                       ...   ...
# 2195  ('콩나물밥(양념장 포함)(반공기)', '우거지국', '훈제닭가슴살')  1959
# 2196   ('콩나물밥(양념장 포함)(반공기)', '우거지국', '계란프라이')  1943
# 2197     ('콩나물밥(양념장 포함)(반공기)', '우거지국', '계란찜')  1942
# 2198   ('콩나물밥(양념장 포함)(반공기)', '우거지국', '계란햄말이')  1944
# 2199  ('콩나물밥(양념장 포함)(반공기)', '우거지국', '쇠고기장조림')  1950
#
# [2200 rows x 2 columns]

# %%
YY.columns
# Out:
# Index(['음식', 0], dtype='object')

# %%
YYY=YY.rename(columns={'음식':'음식',0 :'label'},inplace=True)
YYY

# %%
s=[]
for i in range(len(data)):
  if data['열량(kcal)'][i] < 220:
    s.append(1)
  elif data['열량(kcal)'][i] < 235:
    s.append(2)
  elif data['열량(kcal)'][i] < 250:
    s.append(3)
  elif data['열량(kcal)'][i] < 260:
    s.append(4)
  elif data['열량(kcal)'][i] < 270:
    s.append(5)
  elif data['열량(kcal)'][i] < 275:
    s.append(6)
  elif data['열량(kcal)'][i] < 280:
    s.append(7)
  elif data['열량(kcal)'][i] < 285:
    s.append(8)
  elif data['열량(kcal)'][i] < 290:
    s.append(9)
  elif data['열량(kcal)'][i] < 295:
    s.append(10)
  elif data['열량(kcal)'][i] < 300:
    s.append(11)
  elif data['열량(kcal)'][i] < 305:
    s.append(12)
  elif data['열량(kcal)'][i] < 310:
    s.append(13)
  elif data['열량(kcal)'][i] < 315:
    s.append(14)
  elif data['열량(kcal)'][i] < 320:
    s.append(15)
  elif data['열량(kcal)'][i] < 325:
    s.append(16)
  elif data['열량(kcal)'][i] < 330:
    s.append(17)
  elif data['열량(kcal)'][i] < 335:
    s.append(18)
  elif data['열량(kcal)'][i] < 340:
    s.append(19)
  elif data['열량(kcal)'][i] < 345:
    s.append(20)
  elif data['열량(kcal)'][i] < 350:
    s.append(21)
  elif data['열량(kcal)'][i] < 355:
    s.append(22)
  elif data['열량(kcal)'][i] < 360:
    s.append(23)
  elif data['열량(kcal)'][i] < 365:
    s.append(24)
  elif data['열량(kcal)'][i] < 370:
    s.append(25)
  elif data['열량(kcal)'][i] < 375:
    s.append(26)
  elif data['열량(kcal)'][i] < 383:
    s.append(27)
  elif data['열량(kcal)'][i] < 390:
    s.append(28)
  elif data['열량(kcal)'][i] < 400:
    s.append(29)
  elif data['열량(kcal)'][i] < 410:
    s.append(30)
  elif data['열량(kcal)'][i] < 420:
    s.append(31)
  elif data['열량(kcal)'][i] < 430:
    s.append(32)
  elif data['열량(kcal)'][i] < 440:
    s.append(33)
  elif data['열량(kcal)'][i] < 455:
    s.append(34)
  else:
    s.append(35)

# %%
YY
# Out:
#                                            음식  label
# 0                ('쌀밥(반공기)', '쇠고기국', '콩나물무침')   1676
# 1                ('쌀밥(반공기)', '쇠고기국', '고사리나물')   1665
# 2                 ('쌀밥(반공기)', '쇠고기국', '버섯볶음')   1669
# 3                ('쌀밥(반공기)', '쇠고기국', '진미채볶음')   1674
# 4                 ('쌀밥(반공기)', '쇠고기국', '낚지볶음')   1668
# ...                                       ...    ...
# 2195  ('콩나물밥(양념장 포함)(반공기)', '우거지국', '훈제닭가슴살')   1959
# 2196   ('콩나물밥(양념장 포함)(반공기)', '우거지국', '계란프라이')   1943
# 2197     ('콩나물밥(양념장 포함)(반공기)', '우거지국', '계란찜')   1942
# 2198   ('콩나물밥(양념장 포함)(반공기)', '우거지국', '계란햄말이')   1944
# 2199  ('콩나물밥(양념장 포함)(반공기)', '우거지국', '쇠고기장조림')   1950
#
# [2200 rows x 2 columns]

# %%
YY['구간']=s

# %%
YY
# Out:
#                                            음식  label  구간
# 0                ('쌀밥(반공기)', '쇠고기국', '콩나물무침')   1676   6
# 1                ('쌀밥(반공기)', '쇠고기국', '고사리나물')   1665   8
# 2                 ('쌀밥(반공기)', '쇠고기국', '버섯볶음')   1669  18
# 3                ('쌀밥(반공기)', '쇠고기국', '진미채볶음')   1674  26
# 4                 ('쌀밥(반공기)', '쇠고기국', '낚지볶음')   1668  32
# ...                                       ...    ...  ..
# 2195  ('콩나물밥(양념장 포함)(반공기)', '우거지국', '훈제닭가슴살')   1959  26
# 2196   ('콩나물밥(양념장 포함)(반공기)', '우거지국', '계란프라이')   1943  19
# 2197     ('콩나물밥(양념장 포함)(반공기)', '우거지국', '계란찜')   1942  34
# 2198   ('콩나물밥(양념장 포함)(반공기)', '우거지국', '계란햄말이')   1944  28
# 2199  ('콩나물밥(양념장 포함)(반공기)', '우거지국', '쇠고기장조림')   1950  27
#
# [2200 rows x 3 columns]

# %%
YY.to_csv('/content/drive/MyDrive/캡스톤/최종/foodlabel.csv')

# %%
YY
# Out:
#                                            음식  label
# 0                ('쌀밥(반공기)', '쇠고기국', '콩나물무침')   1676
# 1                ('쌀밥(반공기)', '쇠고기국', '고사리나물')   1665
# 2                 ('쌀밥(반공기)', '쇠고기국', '버섯볶음')   1669
# 3                ('쌀밥(반공기)', '쇠고기국', '진미채볶음')   1674
# 4                 ('쌀밥(반공기)', '쇠고기국', '낚지볶음')   1668
# ...                                       ...    ...
# 2195  ('콩나물밥(양념장 포함)(반공기)', '우거지국', '훈제닭가슴살')   1959
# 2196   ('콩나물밥(양념장 포함)(반공기)', '우거지국', '계란프라이')   1943
# 2197     ('콩나물밥(양념장 포함)(반공기)', '우거지국', '계란찜')   1942
# 2198   ('콩나물밥(양념장 포함)(반공기)', '우거지국', '계란햄말이')   1944
# 2199  ('콩나물밥(양념장 포함)(반공기)', '우거지국', '쇠고기장조림')   1950
#
# [2200 rows x 2 columns]

# %%
YY['구간']=Y['구간']

# %%
YY
# Out:
#                                            음식  label
# 0                ('쌀밥(반공기)', '쇠고기국', '콩나물무침')   1676
# 1                ('쌀밥(반공기)', '쇠고기국', '고사리나물')   1665
# 2                 ('쌀밥(반공기)', '쇠고기국', '버섯볶음')   1669
# 3                ('쌀밥(반공기)', '쇠고기국', '진미채볶음')   1674
# 4                 ('쌀밥(반공기)', '쇠고기국', '낚지볶음')   1668
# ...                                       ...    ...
# 2195  ('콩나물밥(양념장 포함)(반공기)', '우거지국', '훈제닭가슴살')   1959
# 2196   ('콩나물밥(양념장 포함)(반공기)', '우거지국', '계란프라이')   1943
# 2197     ('콩나물밥(양념장 포함)(반공기)', '우거지국', '계란찜')   1942
# 2198   ('콩나물밥(양념장 포함)(반공기)', '우거지국', '계란햄말이')   1944
# 2199  ('콩나물밥(양념장 포함)(반공기)', '우거지국', '쇠고기장조림')   1950
#
# [2200 rows x 2 columns]

# %%
print(np.unique(data['열량(kcal)']))
# Out:
# [156 160 168 169 170 171 172 173 181 182 183 184 186 190 194 195 196 199
#  200 201 202 205 206 207 208 209 211 212 213 214 215 216 217 218 220 221
#  222 223 224 225 226 227 228 229 230 231 232 233 234 235 236 237 238 239
#  240 241 242 243 244 245 246 247 248 249 250 251 252 253 254 255 256 257
#  258 259 260 261 262 263 264 265 266 267 268 269 270 271 272 273 274 275
#  276 277 278 279 280 281 282 283 284 285 286 287 288 289 290 291 292 293
#  294 295 296 297 298 299 300 301 302 303 304 305 306 307 308 309 310 311
#  312 313 314 315 316 317 318 319 320 321 322 323 324 325 326 327 328 329
#  330 331 332 333 334 335 336 337 338 339 340 341 342 343 344 345 346 347
#  348 349 350 351 352 353 354 355 356 357 358 359 360 361 362 363 364 365
#  366 367 368 369 370 371 372 373 374 375 376 377 378 379 380 381 382 383
#  384 385 386 387 388 389 390 391 392 393 394 395 396 397 398 399 400 401
#  402 403 404 405 406 407 408 409 410 411 412 413 414 415 416 417 418 419
# ...

# %%
s= data['열량(kcal)'].value_counts()

# %%
Y['구간']=s

import matplotlib.pyplot as plt
import seaborn as sns

sns.countplot(x="구간", data=Y)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44396 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44036 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 44396 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 44036 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
data['구간']=s

# %%
data
# Out:
#                                            음식  열량(kcal)  탄수화물(kcal)  \
# 0                ('쌀밥(반공기)', '쇠고기국', '콩나물무침')       271         184
# 1                ('쌀밥(반공기)', '쇠고기국', '고사리나물')       283         175
# 2                 ('쌀밥(반공기)', '쇠고기국', '버섯볶음')       331         203
# 3                ('쌀밥(반공기)', '쇠고기국', '진미채볶음')       372         244
# 4                 ('쌀밥(반공기)', '쇠고기국', '낚지볶음')       420         247
# ...                                       ...       ...         ...
# 2195  ('콩나물밥(양념장 포함)(반공기)', '우거지국', '훈제닭가슴살')       374         173
# 2196   ('콩나물밥(양념장 포함)(반공기)', '우거지국', '계란프라이')       338         166
# 2197     ('콩나물밥(양념장 포함)(반공기)', '우거지국', '계란찜')       449         182
# 2198   ('콩나물밥(양념장 포함)(반공기)', '우거지국', '계란햄말이')       387         176
# 2199  ('콩나물밥(양념장 포함)(반공기)', '우거지국', '쇠고기장조림')       381         190
#
#       단백질(kcal)  지방(kcal)  구간
# 0            52        37   6
# 1            51        54   8
# 2            55        88  18
# ...

# %%
print(s.count(1))
print(s.count(2))
print(s.count(3))
print(s.count(4))
print(s.count(5))
print(s.count(6))
print(s.count(7))
print(s.count(8))
print(s.count(9))
print(s.count(10))
print(s.count(11))
print(s.count(12))
print(s.count(13))
print(s.count(14))
# Out:
# 24
# 54
# 15
# 14
# 20
# 32
# 19
# 42
# 35
# 32
# 46
# 39
# 58
# 46

# %%
print(data['구간'].value_counts())
# Out:
# 15    88
# 21    85
# 29    84
# 18    80
# 30    78
# 27    78
# 23    75
# 16    73
# 13    70
# 31    70
# 12    69
# 19    69
# 20    68
# 17    67
# 5     67
# 3     66
# 34    62
# 28    61
# 4     61
# 11    61
# 32    59
# 26    59
# 22    59
# 8     58
# 10    56
# 35    54
# 14    52
# 1     51
# 24    51
# 33    49
# 25    47
# 9     46
# 6     46
# 2     42
# 7     39
# Name: 구간, dtype: int64

# %%
data
# Out:
#                                            음식  열량(kcal)  탄수화물(kcal)  \
# 0                ('쌀밥(반공기)', '쇠고기국', '콩나물무침')       271         184
# 1                ('쌀밥(반공기)', '쇠고기국', '고사리나물')       283         175
# 2                 ('쌀밥(반공기)', '쇠고기국', '버섯볶음')       331         203
# 3                ('쌀밥(반공기)', '쇠고기국', '진미채볶음')       372         244
# 4                 ('쌀밥(반공기)', '쇠고기국', '낚지볶음')       420         247
# ...                                       ...       ...         ...
# 2195  ('콩나물밥(양념장 포함)(반공기)', '우거지국', '훈제닭가슴살')       374         173
# 2196   ('콩나물밥(양념장 포함)(반공기)', '우거지국', '계란프라이')       338         166
# 2197     ('콩나물밥(양념장 포함)(반공기)', '우거지국', '계란찜')       449         182
# 2198   ('콩나물밥(양념장 포함)(반공기)', '우거지국', '계란햄말이')       387         176
# 2199  ('콩나물밥(양념장 포함)(반공기)', '우거지국', '쇠고기장조림')       381         190
#
#       단백질(kcal)  지방(kcal)  구간
# 0            52        37   8
# 1            51        54  10
# 2            55        88  20
# ...

# %%
X
# Out:
#       열량(kcal)  탄수화물(kcal)  단백질(kcal)  지방(kcal)
# 0          271         184         52        37
# 1          283         175         51        54
# 2          331         203         55        88
# 3          372         244         80        45
# 4          420         247        102        67
# ...        ...         ...        ...       ...
# 2195       374         173        147        54
# 2196       338         166         73        92
# 2197       449         182        118       145
# 2198       387         176         81       114
# 2199       381         190        120        68
#
# [2200 rows x 4 columns]

# %%
Y = data.drop(['음식','열량(kcal)','탄수화물(kcal)','단백질(kcal)','지방(kcal)'],axis=1)

# %%
Y
# Out:
#       구간
# 0      6
# 1      8
# 2     18
# 3     26
# 4     32
# ...   ..
# 2195  26
# 2196  19
# 2197  34
# 2198  28
# 2199  27
#
# [2200 rows x 1 columns]

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score

from sklearn.model_selection import train_test_split

np.random.seed(777)

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=777)

param_grid = {
    'max_depth': [25, 30, 40, 45, 50],
    'n_estimators': [20, 50, 100, 150],
    'min_samples_split': [0.005, 0.01, 0.05, 0.1],
}

clf = RandomForestClassifier(random_state=777, class_weight="balanced")

grid = GridSearchCV(clf, param_grid=param_grid, cv=3, refit=True)

grid.fit(X_train, y_train)


estimator = grid.best_estimator_
pred_labels = estimator.predict(X_test)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# ...

# %%
print('GridSearchCV best parameters:', grid.best_params_)
print('GridSearchCV best acc: {0:.2f}'.format(grid.best_score_))

print('Accuracy test : %.2f' % accuracy_score(y_test, pred_labels))
# Out:
# GridSearchCV best parameters: {'max_depth': 25, 'min_samples_split': 0.01, 'n_estimators': 150}
# GridSearchCV best acc: 0.95
# Accuracy test : 0.97

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(random_state=777)

clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_pred)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   after removing the cwd from sys.path.
# 0.953030303030303

# %%
X_train
# Out:
#       열량(kcal)  탄수화물(kcal)  단백질(kcal)  지방(kcal)
# 1102       336         206         56        91
# 1159       368         228         95        42
# 141        257         173         37        38
# 1004       367         229        118        54
# 2          331         203         55        88
# ...        ...         ...        ...       ...
# 1638       335         148         73       105
# 1095       318         157        131        45
# 1130       303         181         34        90
# 1294       444         304         78        93
# 860        169         123         36        29
#
# [1540 rows x 4 columns]

# %%
data['음식']
# Out:
# 0                  ('쌀밥(반공기)', '쇠고기국', '콩나물무침')
# 1                  ('쌀밥(반공기)', '쇠고기국', '고사리나물')
# 2                   ('쌀밥(반공기)', '쇠고기국', '버섯볶음')
# 3                  ('쌀밥(반공기)', '쇠고기국', '진미채볶음')
# 4                   ('쌀밥(반공기)', '쇠고기국', '낚지볶음')
#                          ...
# 2195    ('콩나물밥(양념장 포함)(반공기)', '우거지국', '훈제닭가슴살')
# 2196     ('콩나물밥(양념장 포함)(반공기)', '우거지국', '계란프라이')
# 2197       ('콩나물밥(양념장 포함)(반공기)', '우거지국', '계란찜')
# 2198     ('콩나물밥(양념장 포함)(반공기)', '우거지국', '계란햄말이')
# 2199    ('콩나물밥(양념장 포함)(반공기)', '우거지국', '쇠고기장조림')
# Name: 음식, Length: 2200, dtype: object

# %%
Y['음식']=data['음식']

# %%
import joblib
joblib.dump(estimator, '/content/drive/MyDrive/영양성분표/다이어트.pkl')
# Out:
# ['/content/drive/MyDrive/영양성분표/다이어트.pkl']

# %% [markdown]
# # 다이어트 식단 모델로드

# %%
import joblib
loaded_model = joblib.load('/content/drive/MyDrive/영양성분표/다이어트.pkl')

# %%
test={
    '열량(kcal)':417.216,
    '탄수화물(kcal)':208.5,
    '단백질(kcal)':83.4,
    '지방(kcal)':125.1
}

# %%
import pandas as pd
test=pd.DataFrame([test])

# %%
test
# Out:
#    열량(kcal)  탄수화물(kcal)  단백질(kcal)  지방(kcal)
# 0   417.216       208.5       83.4     125.1

# %%
test.iloc[0]
# Out:
# 열량(kcal)      417.216
# 탄수화물(kcal)    208.500
# 단백질(kcal)      83.400
# 지방(kcal)      125.100
# Name: 0, dtype: float64

# %%
y=loaded_model.predict([test.iloc[0]])
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   "X does not have valid feature names, but"

# %%
label=pd.read_csv('/content/drive/MyDrive/캡스톤/최종/foodlabel.csv')

# %%
food_list = label['음식'][np.where(label['구간'] == y[0])[0]]
cnt = random.randint(0, len(food_list)) 
        
result = food_list.iloc[cnt]

# %%
result
# Out:
# "('강낭콩밥(반공기)', '감자수제비국', '쇠고기장조림')"

# %%
y[0]
# Out:
# 1920

# %%
label['label']
# Out:
# 0       1676
# 1       1665
# 2       1669
# 3       1674
# 4       1668
#         ...
# 2195    1959
# 2196    1943
# 2197    1942
# 2198    1944
# 2199    1950
# Name: label, Length: 2200, dtype: int64

# %%
import numpy as np
# Out:
# 2086

# %%
label['음식'][np.where(label['label'] == y[0])[0][0]]
# Out:
# "('콩나물밥(양념장 포함)(반공기)', '오징어국', '갈치구이')"

# %% [markdown]
# #필요X

# %%
data.head()
# Out:
#                              음식  열량(kcal)  탄수화물(kcal)  단백질(kcal)  지방(kcal)
# 0  ('쌀밥(반공기)', '쇠고기국', '콩나물무침')       271         184         52        37
# 1  ('쌀밥(반공기)', '쇠고기국', '고사리나물')       283         175         51        54
# 2   ('쌀밥(반공기)', '쇠고기국', '버섯볶음')       331         203         55        88
# 3  ('쌀밥(반공기)', '쇠고기국', '진미채볶음')       372         244         80        45
# 4   ('쌀밥(반공기)', '쇠고기국', '낚지볶음')       420         247        102        67

# %%
type(data['음식'][0])
# Out:
# str

# %%
data['음식'][0]
# Out:
# "('쌀밥(반공기)', '쇠고기국', '콩나물무침')"

# %%
data=pd.read_csv('/content/drive/MyDrive/캡스톤/coco/영양성분표_전처리_v1_분류완.csv',encoding='CP949')

# %%
data.columns
# Out:
# Index(['FOOD_CD', 'DESC_KOR', 'MAKER_NAME', 'GROUP_NAME', 'SERVING_SIZE',
#        'NUTR_CONT1', 'NUTR_CONT2', 'NUTR_CONT3', 'NUTR_CONT4', 'NUTR_CONT5',
#        'NUTR_CONT6', 'NUTR_CONT7', 'NUTR_CONT8', 'NUTR_CONT9'],
#       dtype='object')

# %%
for i in range(len(data)):
  if data['GROUP_NAME'][i]=="밥" and data['NUTR_CONT6'][i] < 100 :
    print(data['DESC_KOR'][i])
# Out:
# 곤드레나물밥
# 검정콩밥
# 기장밥
# 보리밥
# 수수밥
# 영양돌솥밥
# 잡곡밥
# 차조밥
# 찰밥
# 팥밥
# 현미밥
# 흑미밥

# %% [markdown]
# # 질병 식단

# %%
SEED = 777

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data=pd.read_excel('/content/gdrive/MyDrive/캡스톤/최종/질병식단.xlsx')

# %%
data.head()
# Out:
#    FOOD_CD DESC_KOR MAKER_NAME GROUP_NAME  SERVING_SIZE  NUTR_CONT1  \
# 0  D000040     무된장국          -          국           450      104.00
# 1  D000041    미소된장국          -          국           150       38.00
# 2  D000054   시래기된장국          -          국           450       99.00
# 3  D000081    초당순두부          -          국           900      522.69
# 4  D018062    냉이된장국          -          국           400       86.47
#
#    NUTR_CONT2  NUTR_CONT3  NUTR_CONT4  NUTR_CONT5  NUTR_CONT6  NUTR_CONT7  \
# 0       14.70        6.10        2.40        5.90     1741.46         0.0
# 1        2.80        2.80        1.80        0.70      517.03         0.0
# 2       11.00        6.70        3.10        1.30     1523.66         0.0
# 3       15.80       49.10       29.20        0.90     1203.36         0.0
# 4        8.81        6.85        2.65        1.18      943.35         0.0
#
#    NUTR_CONT8  NUTR_CONT9   NUTR
# 0        0.30         0.0  콜레스테롤
# 1        0.20         0.0  콜레스테롤
# ...

# %%
data=data.drop(["FOOD_CD","MAKER_NAME","SERVING_SIZE","NUTR_CONT8",	"NUTR_CONT9"],axis=1)

# %%
data=data.rename(columns={'DESC_KOR':'음식', 'GROUP_NAME':'분류', 'NUTR_CONT1':'열량','NUTR_CONT2':'탄수화물', 'NUTR_CONT3':'단백질',
       'NUTR_CONT4':'지방',"NUTR_CONT5":"당류",	"NUTR_CONT6":"나트륨",	"NUTR_CONT7":"콜레스테롤"})

# %%
data

# %%
col_data=data[:28]
na_data=data[29:54]
dan_data=data[55:]

# %%
col_data=col_data.drop(['NUTR'],axis=1)
na_data=na_data.drop(['NUTR'],axis=1)
dan_data=dan_data.drop(['NUTR'],axis=1)

# %%
na_data
# Out:
#        음식  분류      열량   탄수화물    단백질     지방     당류    나트륨  콜레스테롤
# 29  과일샐러드  반찬  138.69  12.95   1.75   8.87  13.02  47.46    5.9
# 30  마늘쫑무침  반찬   31.92   3.83   0.82   1.48   2.24  93.82    0.0
# 31   두부조림  반찬   71.55   2.20   4.82   4.83   1.82  80.66    0.0
# 32  쇠고기수육  반찬  498.92   6.11  85.29  14.81   0.33  91.81  264.9
# 33    기장밥   밥  331.91  73.53   6.87   1.14   0.00   2.79    0.0
# 34   검정콩밥   밥  330.61  68.59   9.06   2.23   0.00   6.87    0.0
# 35    보리밥   밥  321.63  73.54   5.80   0.48   5.14   7.85    0.0
# 36    수수밥   밥  321.89  70.04   6.31   1.83   0.15   2.55    0.0
# 37    현미밥   밥  396.31  89.48   7.14   1.09   0.00   4.80    0.0
# 38    흑미밥   밥  348.70  80.14   6.53   0.22   0.04   3.51    0.0
# 63     사과  과일   52.00  13.81   0.26   0.17   0.00   0.00    0.0
# 64     포도  과일   69.00  18.00   0.72   0.16   0.00   0.00    0.0
# 65    오렌지  과일   62.00  15.39   1.23   0.16   0.00   0.00    0.0
# 66     딸기  과일   26.54   2.35   3.05  18.81  24.03   0.00    0.0

# %%
#list(combinations(nums,3))

col_rice=[]
i_rice=[]
col_soup=[]
i_soup=[]
col_side=[]
i_side=[]

for i in range(len(col_data['분류'])):
  if col_data['분류'][i]=="반찬":
    col_side.append(col_data['음식'][i])
    i_side.append(col_data.iloc[i])
  elif col_data['분류'][i]=="국":
    col_soup.append(col_data['음식'][i])
    i_soup.append(col_data.iloc[i])
  else:
    col_rice.append(col_data['음식'][i])
    i_rice.append(col_data.iloc[i])

print(len(col_rice))
print(len(col_soup))
print(len(col_side))
# Out:
# 7
# 7
# 14

# %%
from itertools import product

meal=[col_rice,col_soup,col_side]

col_m=list(product(*meal))

# %%
len(col_m)
# Out:
# 686

# %%
food_combi=pd.DataFrame(columns={"음식","열량","탄수화물","단백질","지방","당류","나트륨",'콜레스테롤'})

# NUTR_CONT1':'열량','NUTR_CONT2':'탄수화물', 'NUTR_CONT3':'단백질','NUTR_CONT4':'지방'
#당류	나트륨	콜레스테롤

from tqdm.notebook import tqdm

for i in tqdm(range(0,len(col_m))):
  nr1=0
  nr2=0
  nr3=0
  nr4=0
  nr5=0
  nr6=0
  nr7=0
  ri=col_rice.index(col_m[i][0])
  so=col_soup.index(col_m[i][1])
  si=col_side.index(col_m[i][2])
  nr1=int(i_rice[ri]["열량"])+int(i_soup[so]["열량"])+int(i_side[si]["열량"])
  nr2=int(i_rice[ri]["탄수화물"])+int(i_soup[so]["탄수화물"])+int(i_side[si]["탄수화물"])
  nr3=int(i_rice[ri]["단백질"])+int(i_soup[so]["단백질"])+int(i_side[si]["단백질"])
  nr4=int(i_rice[ri]["지방"])+int(i_soup[so]["지방"])+int(i_side[si]["지방"])
  nr5=int(i_rice[ri]["당류"])+int(i_soup[so]["당류"])+int(i_side[si]["당류"])
  nr6=int(i_rice[ri]["나트륨"])+int(i_soup[so]["나트륨"])+int(i_side[si]["나트륨"])
  nr7=int(i_rice[ri]["콜레스테롤"])+int(i_soup[so]["콜레스테롤"])+int(i_side[si]["콜레스테롤"])
  combi={"음식":col_m[i],"열량":nr1,"탄수화물":nr2,"단백질":nr3,"지방":nr4,"당류":nr5,"나트륨":nr6,"콜레스테롤":nr7}   
  food_combi=food_combi.append(combi,ignore_index=True)
food_combi=food_combi[["음식","열량","탄수화물","단백질","지방","당류","나트륨","콜레스테롤"]] 

dataframe=pd.DataFrame(food_combi)

dataframe.to_csv("/content/gdrive/MyDrive/캡스톤/최종/콜레스테롤식단.csv",index=False, header=True)
# Out:
#   0%|          | 0/686 [00:00<?, ?it/s]

# %%
len(dan_data)
# Out:
# 26

# %%
dan_data
# Out:
#         음식  분류      열량   탄수화물    단백질     지방    당류      나트륨   콜레스테롤
# 55     잡곡밥   밥  292.60  58.65  10.59   1.74  0.64     5.29    0.00
# 56     차조밥   밥  313.24  69.71   5.67   1.30  0.07     2.81    0.00
# 57      찰밥   밥  429.70  93.97  12.30   0.51  1.37     9.35    0.00
# 58    콩나물밥   밥  392.17  71.66  14.98   5.07  0.12   868.99   10.06
# 59     흑미밥   밥  348.70  80.14   6.53   0.22  0.04     3.51    0.00
# 60    검정콩밥   밥  330.61  68.59   9.06   2.23  0.00     6.87    0.00
# 61    완두콩밥   밥  276.32  62.49   5.89   0.31  0.00   590.06    0.00
# 62  곤드레나물밥   밥  521.83  98.90  10.30   9.50  0.00    90.62    0.00
# 63  바지락조개국   국  157.00  10.10  22.00   3.10  1.30  1596.17   89.36
# 64  얼갈이배춧국   국   36.23   3.41   2.00   1.62  0.22   778.53    0.00
# 65   홍합미역국   국  167.00  11.60  19.70   4.70  0.00  2043.68   58.40
# 66    무된장국   국  104.00  14.70   6.10   2.40  5.90  1741.46    0.00
# 67   황태해장국   국  181.70   5.70  24.50   6.80  1.50  1533.09  150.30
# ...

# %%
dan_data.iloc[0]
# Out:
# 음식         잡곡밥
# 분류           밥
# 열량       292.6
# 탄수화물     58.65
# 단백질      10.59
# 지방        1.74
# 당류        0.64
# 나트륨       5.29
# 콜레스테롤      0.0
# Name: 40, dtype: object

# %%
#list(combinations(nums,3))

dan_rice=[]
i_rice=[]
dan_soup=[]
i_soup=[]
dan_side=[]
i_side=[]

for i in range(55,81):
  if dan_data['분류'][i]=="반찬":
    dan_side.append(dan_data['음식'][i])
    i_side.append(dan_data.iloc[i-55])
  elif dan_data['분류'][i]=="국":
    dan_soup.append(dan_data['음식'][i])
    i_soup.append(dan_data.iloc[i-55])
  else:
    dan_rice.append(dan_data['음식'][i])
    i_rice.append(dan_data.iloc[i-55])

print(len(dan_rice))
print(len(dan_soup))
print(len(dan_side))
# Out:
# 8
# 8
# 10

# %%
from itertools import product

meal=[dan_rice,dan_soup,dan_side]

dan_m=list(product(*meal))

# %%
food_combi=pd.DataFrame(columns={"음식","열량","탄수화물","단백질","지방","당류","나트륨",'콜레스테롤'})

# NUTR_CONT1':'열량','NUTR_CONT2':'탄수화물', 'NUTR_CONT3':'단백질','NUTR_CONT4':'지방'
#당류	나트륨	콜레스테롤

from tqdm.notebook import tqdm

for i in tqdm(range(0,len(dan_m))):
  nr1=0
  nr2=0
  nr3=0
  nr4=0
  nr5=0
  nr6=0
  nr7=0
  ri=dan_rice.index(dan_m[i][0])
  so=dan_soup.index(dan_m[i][1])
  si=dan_side.index(dan_m[i][2])
  nr1=int(i_rice[ri]["열량"])+int(i_soup[so]["열량"])+int(i_side[si]["열량"])
  nr2=int(i_rice[ri]["탄수화물"])+int(i_soup[so]["탄수화물"])+int(i_side[si]["탄수화물"])
  nr3=int(i_rice[ri]["단백질"])+int(i_soup[so]["단백질"])+int(i_side[si]["단백질"])
  nr4=int(i_rice[ri]["지방"])+int(i_soup[so]["지방"])+int(i_side[si]["지방"])
  nr5=int(i_rice[ri]["당류"])+int(i_soup[so]["당류"])+int(i_side[si]["당류"])
  nr6=int(i_rice[ri]["나트륨"])+int(i_soup[so]["나트륨"])+int(i_side[si]["나트륨"])
  nr7=int(i_rice[ri]["콜레스테롤"])+int(i_soup[so]["콜레스테롤"])+int(i_side[si]["콜레스테롤"])
  combi={"음식":dan_m[i],"열량":nr1,"탄수화물":nr2,"단백질":nr3,"지방":nr4,"당류":nr5,"나트륨":nr6,"콜레스테롤":nr7}   
  food_combi=food_combi.append(combi,ignore_index=True)
food_combi=food_combi[["음식","열량","탄수화물","단백질","지방","당류","나트륨","콜레스테롤"]] 

dataframe=pd.DataFrame(food_combi)

dataframe.to_csv("/content/gdrive/MyDrive/캡스톤/최종/당뇨식단.csv",index=False, header=True)
# Out:
#   0%|          | 0/640 [00:00<?, ?it/s]

# %%
dataframe
# Out:
#                         음식   열량 탄수화물 단백질  지방 당류   나트륨 콜레스테롤
# 0     (잡곡밥, 바지락조개국, 미나리나물)  478   70  33   5  1  1751    89
# 1       (잡곡밥, 바지락조개국, 취나물)  523   71  33  10  1  1882    89
# 2      (잡곡밥, 바지락조개국, 도토리묵)  494   78  32   4  1  1725    89
# 3      (잡곡밥, 바지락조개국, 새우구이)  709   73  74  11  1  2194   510
# 4    (잡곡밥, 바지락조개국, 숙주나물무침)  466   69  33   4  1  1802    89
# ..                     ...  ...  ...  ..  .. ..   ...   ...
# 443    (곤드레나물밥, 미역국, 새우구이)  827  106  54  18  1  1353   421
# 444  (곤드레나물밥, 미역국, 숙주나물무침)  584  102  13  11  1   961     0
# 445   (곤드레나물밥, 미역국, 애호박볶음)  596  103  12  12  1   983     0
# 446   (곤드레나물밥, 미역국, 청포묵무침)  716  123  14  16  2  1484     0
# 447  (곤드레나물밥, 미역국, 쑥갓나물무침)  663  107  16  16  1  1469     0
#
# [448 rows x 8 columns]

# %%
na_data.iloc[0]
# Out:
# 음식        과일샐러드
# 분류           반찬
# 열량       138.69
# 탄수화물      12.95
# 단백질        1.75
# 지방         8.87
# 당류        13.02
# 나트륨       47.46
# 콜레스테롤       5.9
# Name: 29, dtype: object

# %%
na_data=na_data.reset_index(drop=True)

# %%
#list(combinations(nums,3))

na_rice=[]
i_rice=[]
na_soup=[]
i_soup=[]
na_side=[]
i_side=[]

for i in range(len(na_data)):
  if na_data['분류'][i]=="반찬":
    na_side.append(na_data['음식'][i])
    i_side.append(na_data.iloc[i])
  elif na_data['분류'][i]=="디저트":
    na_soup.append(na_data['음식'][i])
    i_soup.append(na_data.iloc[i])
  else:
    na_rice.append(na_data['음식'][i])
    i_rice.append(na_data.iloc[i])

print(len(na_rice))
print(len(na_soup))
print(len(na_side))
# Out:
# 7
# 7
# 11

# %%
from itertools import product

meal=[na_rice,na_soup,na_side]

na_m=list(product(*meal))

# %%
food_combi=pd.DataFrame(columns={"음식","열량","탄수화물","단백질","지방","당류","나트륨",'콜레스테롤'})

# NUTR_CONT1':'열량','NUTR_CONT2':'탄수화물', 'NUTR_CONT3':'단백질','NUTR_CONT4':'지방'
#당류	나트륨	콜레스테롤

from tqdm.notebook import tqdm

for i in tqdm(range(0,len(na_m))):
  nr1=0
  nr2=0
  nr3=0
  nr4=0
  nr5=0
  nr6=0
  nr7=0
  ri=na_rice.index(na_m[i][0])
  so=na_soup.index(na_m[i][1])
  si=na_side.index(na_m[i][2])
  nr1=int(i_rice[ri]["열량"])+int(i_soup[so]["열량"])+int(i_side[si]["열량"])
  nr2=int(i_rice[ri]["탄수화물"])+int(i_soup[so]["탄수화물"])+int(i_side[si]["탄수화물"])
  nr3=int(i_rice[ri]["단백질"])+int(i_soup[so]["단백질"])+int(i_side[si]["단백질"])
  nr4=int(i_rice[ri]["지방"])+int(i_soup[so]["지방"])+int(i_side[si]["지방"])
  nr5=int(i_rice[ri]["당류"])+int(i_soup[so]["당류"])+int(i_side[si]["당류"])
  nr6=int(i_rice[ri]["나트륨"])+int(i_soup[so]["나트륨"])+int(i_side[si]["나트륨"])
  nr7=int(i_rice[ri]["콜레스테롤"])+int(i_soup[so]["콜레스테롤"])+int(i_side[si]["콜레스테롤"])
  combi={"음식":na_m[i],"열량":nr1,"탄수화물":nr2,"단백질":nr3,"지방":nr4,"당류":nr5,"나트륨":nr6,"콜레스테롤":nr7}   
  food_combi=food_combi.append(combi,ignore_index=True)
food_combi=food_combi[["음식","열량","탄수화물","단백질","지방","당류","나트륨","콜레스테롤"]] 

dataframe=pd.DataFrame(food_combi)

dataframe.to_csv("/content/gdrive/MyDrive/캡스톤/최종/나트륨식단.csv",index=False, header=True)
# Out:
#   0%|          | 0/539 [00:00<?, ?it/s]

# %%
dataframe=pd.read_csv('/content/gdrive/MyDrive/캡스톤/최종/당뇨식단.csv')

# %%
dataframe
# Out:
#                               음식    열량  탄수화물  단백질  지방  당류   나트륨  콜레스테롤
# 0     ('잡곡밥', '바지락조개국', '미나리나물')   478    70   33   5   1  1751     89
# 1       ('잡곡밥', '바지락조개국', '취나물')   523    71   33  10   1  1882     89
# 2      ('잡곡밥', '바지락조개국', '도토리묵')   494    78   32   4   1  1725     89
# 3      ('잡곡밥', '바지락조개국', '새우구이')   709    73   74  11   1  2194    510
# 4    ('잡곡밥', '바지락조개국', '숙주나물무침')   466    69   33   4   1  1802     89
# ..                           ...   ...   ...  ...  ..  ..   ...    ...
# 635   ('곤드레나물밥', '미역국', '애호박볶음')   596   103   12  12   1   983      0
# 636   ('곤드레나물밥', '미역국', '청포묵무침')   716   123   14  16   2  1484      0
# 637    ('곤드레나물밥', '미역국', '병어구이')  1055   101   66  41   1  2327    198
# 638  ('곤드레나물밥', '미역국', '쑥갓나물무침')   663   107   16  16   1  1469      0
# 639    ('곤드레나물밥', '미역국', '도미구이')   964   103   73  27   1  2342    211
#
# [640 rows x 8 columns]

# %% [markdown]
# ## 콜레스테롤 관련 질병
#
# 동맥 경화 / 고지혈증

# %%
data=pd.read_csv('/content/drive/MyDrive/캡스톤/최종/콜레스테롤식단.csv')

# %%
data.head()
# Out:
#                              음식    열량  탄수화물  단백질  지방  당류   나트륨  콜레스테롤
# 0  ('곤드레나물밥', '무된장국', '도토리묵말이')  1087   201   22  19  11  5037      0
# 1   ('곤드레나물밥', '무된장국', '콩나물무침')   659   113   17  13   5  2024      0
# 2     ('곤드레나물밥', '무된장국', '취나물')   699   115   17  17   5  2112      0
# 3   ('곤드레나물밥', '무된장국', '미나리나물')   654   114   17  12   5  1981      0
# 4  ('곤드레나물밥', '무된장국', '달래나물무침')   761   135   20  13  16  2698      0

# %%
print(np.unique(data['열량']))
# Out:
# [ 321  329  333  338  341  345  346  348  349  353  356  357  369  370
#   376  378  381  382  384  386  387  388  393  394  396  397  398  399
#   400  401  403  404  406  408  409  410  411  412  414  415  418  419
#   424  425  426  427  431  433  436  437  439  440  441  442  443  444
#   446  448  449  451  452  453  454  455  459  460  461  463  464  465
#   466  467  468  469  470  471  473  474  475  478  479  481  482  486
#   488  489  491  492  494  495  499  500  501  502  503  504  506  507
#   508  509  510  512  514  515  516  518  519  520  521  526  528  531
#   532  533  536  537  540  541  543  544  548  549  550  553  556  557
#   558  559  561  562  565  566  567  568  569  570  571  573  574  575
#   576  578  581  583  584  586  588  590  591  593  594  596  598  600
#   601  602  603  604  608  610  611  612  613  614  615  616  617  623
#   624  625  626  627  628  629  631  632  633  634  636  637  638  639
# ...

# %%
data=data.rename(columns={'열량':'열량(kcal)'})

# %%
s=[]
for i in range(len(data)):
  if data['열량(kcal)'][i] < 381:
    s.append(1)
  elif data['열량(kcal)'][i] < 400:
    s.append(2)
  elif data['열량(kcal)'][i] < 420:
    s.append(3)
  elif data['열량(kcal)'][i] < 444:
    s.append(4)
  elif data['열량(kcal)'][i] < 466:
    s.append(5)
  elif data['열량(kcal)'][i] < 487:
    s.append(6)
  elif  data['열량(kcal)'][i] < 508:
    s.append(7)
  elif data['열량(kcal)'][i] < 535:
    s.append(8)
  elif data['열량(kcal)'][i] < 566:
    s.append(9)
  elif data['열량(kcal)'][i] < 580:
    s.append(10)
  elif data['열량(kcal)'][i] < 610:
    s.append(11)
  elif data['열량(kcal)'][i] < 630:
    s.append(12)
  elif data['열량(kcal)'][i] < 643:
    s.append(13)
  elif data['열량(kcal)'][i] < 657:
    s.append(14)
  elif data['열량(kcal)'][i] < 677:
    s.append(15)
  elif data['열량(kcal)'][i] < 700:
    s.append(16)
  elif data['열량(kcal)'][i] < 748:
    s.append(17)
  elif data['열량(kcal)'][i] < 767:
    s.append(18)
  elif data['열량(kcal)'][i] < 818:
    s.append(19)
  elif data['열량(kcal)'][i] < 870:
    s.append(20)
  elif data['열량(kcal)'][i] < 980:
    s.append(21)
  elif data['열량(kcal)'][i] < 1080:
    s.append(22)
  else:
    s.append(23)

# %%
data['구간']=s

# %%
data
# Out:
#                                음식  열량(kcal)  탄수화물  단백질  지방  당류   나트륨  콜레스테롤  \
# 0    ('곤드레나물밥', '무된장국', '도토리묵말이')      1087   201   22  19  11  5037      0
# 1     ('곤드레나물밥', '무된장국', '콩나물무침')       659   113   17  13   5  2024      0
# 2       ('곤드레나물밥', '무된장국', '취나물')       699   115   17  17   5  2112      0
# 3     ('곤드레나물밥', '무된장국', '미나리나물')       654   114   17  12   5  1981      0
# 4    ('곤드레나물밥', '무된장국', '달래나물무침')       761   135   20  13  16  2698      0
# ..                            ...       ...   ...  ...  ..  ..   ...    ...
# 681   ('곤드레나물밥', '미역국', '표고버섯볶음')       709   116   16  17   3  1334      0
# 682     ('곤드레나물밥', '미역국', '버섯구이')       608   104   16  12   1  1153      0
# 683  ('곤드레나물밥', '미역국', '새송이버섯구이')       633   110   15  12   4  1130      0
# 684   ('곤드레나물밥', '미역국', '가지나물무침')       584   103   12  11   2   897      0
# 685  ('곤드레나물밥', '미역국', '고사리나물무침')       611   104   13  13   1   980      0
#
#      구간
# 0    23
# 1    15
# 2    16
# 3    14
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.countplot(x="구간", data=data)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44396 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44036 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 44396 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 44036 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
'''
for i in range(len(data)):
  data['나트륨'][i]=data['나트륨'][i]/1000

for i in range(len(data)):
  try:
    data['콜레스테롤'][i]=data['콜레스테롤'][i]/1000
  except:
    data['콜레스테롤'][i]=0
'''
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
X = data.drop('음식', axis = 1)
Y= data.drop(['음식','열량(kcal)','탄수화물','단백질','지방','당류','나트륨','콜레스테롤'],axis=1)

# %%
Y
# Out:
#      구간
# 0    23
# 1    15
# 2    16
# 3    14
# 4    18
# ..   ..
# 681  17
# 682  11
# 683  13
# 684  11
# 685  12
#
# [686 rows x 1 columns]

# %%
X = data.drop('음식', axis = 1)
Y= data.drop(['열량(kcal)','탄수화물','단백질','지방','당류','나트륨','콜레스테롤'],axis=1)

from sklearn import preprocessing
le = preprocessing.LabelEncoder()
Y = le.fit_transform(Y['음식'])
label=Y
label=pd.DataFrame([label])
label=label.transpose()

# %%
data=pd.read_csv('/content/drive/MyDrive/캡스톤/최종/콜레스테롤식단.csv')

# %%
for i in range(len(data)):
  data['나트륨'][i]=data['나트륨'][i]/1000
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
for i in range(len(data)):
  try:
    data['콜레스테롤'][i]=data['콜레스테롤'][i]/1000
  except:
    data['콜레스테롤'][i]=0
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
X = data.drop('음식', axis = 1)
Y= data.drop(['열량','탄수화물','단백질','지방','당류','나트륨','콜레스테롤'],axis=1)

# %%
Y=pd.concat([Y,label],axis=1)

# %%
Y
# Out:
#                                음식   0
# 0    ('곤드레나물밥', '무된장국', '도토리묵말이')  34
# 1     ('곤드레나물밥', '무된장국', '콩나물무침')  40
# 2       ('곤드레나물밥', '무된장국', '취나물')  39
# 3     ('곤드레나물밥', '무된장국', '미나리나물')  35
# 4    ('곤드레나물밥', '무된장국', '달래나물무침')  31
# ..                            ...  ..
# 681   ('곤드레나물밥', '미역국', '표고버섯볶음')  69
# 682     ('곤드레나물밥', '미역국', '버섯구이')  64
# 683  ('곤드레나물밥', '미역국', '새송이버섯구이')  65
# 684   ('곤드레나물밥', '미역국', '가지나물무침')  56
# 685  ('곤드레나물밥', '미역국', '고사리나물무침')  57
#
# [686 rows x 2 columns]

# %%
Y['label']=Y[0]

# %%
Y
# Out:
#                                음식   0  label
# 0    ('곤드레나물밥', '무된장국', '도토리묵말이')  34     34
# 1     ('곤드레나물밥', '무된장국', '콩나물무침')  40     40
# 2       ('곤드레나물밥', '무된장국', '취나물')  39     39
# 3     ('곤드레나물밥', '무된장국', '미나리나물')  35     35
# 4    ('곤드레나물밥', '무된장국', '달래나물무침')  31     31
# ..                            ...  ..    ...
# 681   ('곤드레나물밥', '미역국', '표고버섯볶음')  69     69
# 682     ('곤드레나물밥', '미역국', '버섯구이')  64     64
# 683  ('곤드레나물밥', '미역국', '새송이버섯구이')  65     65
# 684   ('곤드레나물밥', '미역국', '가지나물무침')  56     56
# 685  ('곤드레나물밥', '미역국', '고사리나물무침')  57     57
#
# [686 rows x 3 columns]

# %%
Y.columns
# Out:
# Index(['음식', 0, 'label'], dtype='object')

# %%
Y = Y.drop(0, axis = 1)

# %%
Y['구간']=s

# %%
Y
# Out:
#                                음식  label  구간
# 0    ('곤드레나물밥', '무된장국', '도토리묵말이')     34  23
# 1     ('곤드레나물밥', '무된장국', '콩나물무침')     40  15
# 2       ('곤드레나물밥', '무된장국', '취나물')     39  16
# 3     ('곤드레나물밥', '무된장국', '미나리나물')     35  14
# 4    ('곤드레나물밥', '무된장국', '달래나물무침')     31  18
# ..                            ...    ...  ..
# 681   ('곤드레나물밥', '미역국', '표고버섯볶음')     69  17
# 682     ('곤드레나물밥', '미역국', '버섯구이')     64  11
# 683  ('곤드레나물밥', '미역국', '새송이버섯구이')     65  13
# 684   ('곤드레나물밥', '미역국', '가지나물무침')     56  11
# 685  ('곤드레나물밥', '미역국', '고사리나물무침')     57  12
#
# [686 rows x 3 columns]

# %%
print(s.count(1))
print(s.count(2))
print(s.count(3))
print(s.count(4))
print(s.count(5))
print(s.count(6))
print(s.count(7))
print(s.count(8))
print(s.count(9))
print(s.count(10))
print(s.count(11))
print(s.count(12))
print(s.count(13))
print(s.count(14))
print(s.count(15))
print(s.count(16))
print(s.count(17))
print(s.count(18))
print(s.count(19))
print(s.count(20))
# Out:
# 19
# 24
# 23
# 31
# 36
# 23
# 29
# 31
# 32
# 24
# 32
# 37
# 40
# 27
# 25
# 28
# 24
# 25
# 27
# 31

# %%
Y.to_csv('/content/drive/MyDrive/캡스톤/최종/chol_foodlabel.csv')

# %%
da= pd.read_csv('/content/drive/MyDrive/캡스톤/최종/chol_foodlabel.csv')

# %%
da
# Out:
#      Unnamed: 0                            음식  label  구간
# 0             0  ('곤드레나물밥', '무된장국', '도토리묵말이')     34  23
# 1             1   ('곤드레나물밥', '무된장국', '콩나물무침')     40  15
# 2             2     ('곤드레나물밥', '무된장국', '취나물')     39  16
# 3             3   ('곤드레나물밥', '무된장국', '미나리나물')     35  14
# 4             4  ('곤드레나물밥', '무된장국', '달래나물무침')     31  18
# ..          ...                           ...    ...  ..
# 681         681   ('곤드레나물밥', '미역국', '표고버섯볶음')     69  17
# 682         682     ('곤드레나물밥', '미역국', '버섯구이')     64  11
# 683         683  ('곤드레나물밥', '미역국', '새송이버섯구이')     65  13
# 684         684   ('곤드레나물밥', '미역국', '가지나물무침')     56  11
# 685         685  ('곤드레나물밥', '미역국', '고사리나물무침')     57  12
#
# [686 rows x 4 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.countplot(x="구간", data=da)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44396 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44036 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 44396 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 44036 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
Y=Y.drop(['음식'],axis=1)

# %%
Y=Y.drop(['label'],axis=1)

# %%
import numpy as np

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=777)

from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(random_state=777)

clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_pred)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# 0.8932038834951457

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score

from sklearn.model_selection import train_test_split

np.random.seed(777)

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=777)

param_grid = {
    'max_depth': [25, 30, 40, 45, 50],
    'n_estimators': [20, 50, 100, 150],
    'min_samples_split': [0.005, 0.01, 0.05, 0.1],
}

clf = RandomForestClassifier(random_state=777, class_weight="balanced")

grid = GridSearchCV(clf, param_grid=param_grid, cv=3, refit=True)

grid.fit(X_train, y_train)


estimator = grid.best_estimator_
pred_labels = estimator.predict(X_test)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# ...

# %%
print('GridSearchCV best parameters:', grid.best_params_)
print('GridSearchCV best acc: {0:.2f}'.format(grid.best_score_))

print('Accuracy test : %.2f' % accuracy_score(y_test, pred_labels))
# Out:
# GridSearchCV best parameters: {'max_depth': 25, 'min_samples_split': 0.005, 'n_estimators': 100}
# GridSearchCV best acc: 0.86
# Accuracy test : 0.96

# %%
print('GridSearchCV best parameters:', grid.best_params_)
print('GridSearchCV best acc: {0:.2f}'.format(grid.best_score_))

print('Accuracy test : %.2f' % accuracy_score(y_test, pred_labels))
# Out:
# GridSearchCV best parameters: {'max_depth': 25, 'min_samples_split': 0.005, 'n_estimators': 100}
# GridSearchCV best acc: 0.86
# Accuracy test : 0.96

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=42)

from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(random_state=777)

clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_pred)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   import sys
# 0.8980582524271845

# %%
import joblib
joblib.dump(estimator, '/content/drive/MyDrive/캡스톤/최종/cholesterol.pkl')
# Out:
# ['/content/drive/MyDrive/캡스톤/최종/cholesterol.pkl']

# %% [markdown]
# ## 당뇨병 관련 질병

# %%
data=pd.read_csv('/content/drive/MyDrive/캡스톤/최종/당뇨식단.csv')

# %%
data.head()
# Out:
#                             음식   열량  탄수화물  단백질  지방  당류   나트륨  콜레스테롤
# 0   ('잡곡밥', '바지락조개국', '미나리나물')  478    70   33   5   1  1751     89
# 1     ('잡곡밥', '바지락조개국', '취나물')  523    71   33  10   1  1882     89
# 2    ('잡곡밥', '바지락조개국', '도토리묵')  494    78   32   4   1  1725     89
# 3    ('잡곡밥', '바지락조개국', '새우구이')  709    73   74  11   1  2194    510
# 4  ('잡곡밥', '바지락조개국', '숙주나물무침')  466    69   33   4   1  1802     89

# %%
print(round(1700/1000,2))
# Out:
# 1.7

# %%
for i in range(len(data)):
  data['나트륨'][i] = round(data['나트륨'][i]/1000,2)

for i in range(len(data)):
  try:
    data['콜레스테롤'][i]=round(data['콜레스테롤'][i]/1000,2)
  except:
    data['콜레스테롤'][i]=0
# Out:
#   File "<ipython-input-172-e09ce9d61da9>", line 2
#     float(data['나트륨'][i])= round(data['나트륨'][i]/1000,2)
#     ^
# SyntaxError: can't assign to function call

# %%
data
# Out:
#                               음식    열량  탄수화물  단백질  지방  당류  나트륨  콜레스테롤
# 0     ('잡곡밥', '바지락조개국', '미나리나물')   478    70   33   5   1    1      0
# 1       ('잡곡밥', '바지락조개국', '취나물')   523    71   33  10   1    1      0
# 2      ('잡곡밥', '바지락조개국', '도토리묵')   494    78   32   4   1    1      0
# 3      ('잡곡밥', '바지락조개국', '새우구이')   709    73   74  11   1    2      0
# 4    ('잡곡밥', '바지락조개국', '숙주나물무침')   466    69   33   4   1    1      0
# ..                           ...   ...   ...  ...  ..  ..  ...    ...
# 635   ('곤드레나물밥', '미역국', '애호박볶음')   596   103   12  12   1    0      0
# 636   ('곤드레나물밥', '미역국', '청포묵무침')   716   123   14  16   2    1      0
# 637    ('곤드레나물밥', '미역국', '병어구이')  1055   101   66  41   1    2      0
# 638  ('곤드레나물밥', '미역국', '쑥갓나물무침')   663   107   16  16   1    1      0
# 639    ('곤드레나물밥', '미역국', '도미구이')   964   103   73  27   1    2      0
#
# [640 rows x 8 columns]

# %%
print(np.unique(data['열량']))
# Out:
# [ 329  339  341  345  351  355  357  366  367  373  375  376  378  383
#   386  387  388  391  393  394  395  396  397  401  402  403  404  405
#   408  409  411  412  413  418  419  421  423  424  425  429  432  433
#   434  439  440  441  444  445  446  447  448  450  451  454  455  456
#   457  458  459  460  461  462  463  466  467  468  469  470  471  472
#   473  474  475  476  477  478  479  480  481  482  483  486  487  488
#   490  491  492  493  494  497  498  499  501  502  503  504  507  508
#   509  510  511  512  513  514  515  516  517  518  519  520  522  523
#   524  525  526  528  529  530  531  532  533  534  538  539  540  541
#   542  543  544  545  546  547  548  549  550  553  554  555  556  558
#   560  561  562  566  568  569  570  571  572  573  574  576  577  578
#   579  582  583  584  585  586  587  588  589  590  592  593  594  595
#   596  597  598  601  602  603  604  606  607  608  609  611  612  613
# ...

# %%
data=data.rename(columns={'열량':'열량(kcal)'})

# %%
s=[]
for i in range(len(data)):
  if data['열량(kcal)'][i] < 400:
    s.append(1)
  elif data['열량(kcal)'][i] < 430:
    s.append(2)
  elif data['열량(kcal)'][i] < 460:
    s.append(3)
  elif data['열량(kcal)'][i] < 480:
    s.append(4)
  elif data['열량(kcal)'][i] < 500:
    s.append(5)
  elif data['열량(kcal)'][i] < 520:
    s.append(6)
  elif data['열량(kcal)'][i] < 540:
    s.append(7)
  elif data['열량(kcal)'][i] < 570:
    s.append(8)
  elif data['열량(kcal)'][i] < 600:
    s.append(9)
  elif data['열량(kcal)'][i] < 635:
    s.append(10)
  elif data['열량(kcal)'][i] < 690:
    s.append(11)
  elif data['열량(kcal)'][i] < 730:
    s.append(12)
  elif data['열량(kcal)'][i] < 790:
    s.append(13)
  elif data['열량(kcal)'][i] < 860:
    s.append(14)
  elif data['열량(kcal)'][i] < 930:
    s.append(15)
  elif data['열량(kcal)'][i] < 990:
    s.append(16)
  else:
    s.append(17)

# %%
data['구간']=s

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.countplot(x="구간", data=data)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44396 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44036 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 44396 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 44036 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
X = data.drop(['음식','구간'], axis = 1)
Y= data.drop(['열량(kcal)','탄수화물','단백질','지방','당류','나트륨','콜레스테롤'],axis=1)

# %%
Y
# Out:
#                               음식  구간
# 0     ('잡곡밥', '바지락조개국', '미나리나물')   4
# 1       ('잡곡밥', '바지락조개국', '취나물')   7
# 2      ('잡곡밥', '바지락조개국', '도토리묵')   5
# 3      ('잡곡밥', '바지락조개국', '새우구이')  12
# 4    ('잡곡밥', '바지락조개국', '숙주나물무침')   4
# ..                           ...  ..
# 635   ('곤드레나물밥', '미역국', '애호박볶음')   9
# 636   ('곤드레나물밥', '미역국', '청포묵무침')  12
# 637    ('곤드레나물밥', '미역국', '병어구이')  17
# 638  ('곤드레나물밥', '미역국', '쑥갓나물무침')  11
# 639    ('곤드레나물밥', '미역국', '도미구이')  16
#
# [640 rows x 2 columns]

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
Y = le.fit_transform(Y['음식'])
label=Y
label=pd.DataFrame([label])
label=label.transpose()

# %%
label
# Out:
#        0
# 0    272
# 1    279
# 2    271
# 3    274
# 4    275
# ..   ...
# 635  107
# 636  108
# 637  103
# 638  106
# 639  100
#
# [640 rows x 1 columns]

# %%
data=pd.read_csv('/content/drive/MyDrive/캡스톤/최종/당뇨식단.csv')

# %%
X = data.drop(['음식'], axis = 1)
Y= data.drop(['열량','탄수화물','단백질','지방','당류','나트륨','콜레스테롤'],axis=1)

# %%
X
# Out:
#        열량  탄수화물  단백질  지방  당류   나트륨  콜레스테롤
# 0     478    70   33   5   1  1751     89
# 1     523    71   33  10   1  1882     89
# 2     494    78   32   4   1  1725     89
# 3     709    73   74  11   1  2194    510
# 4     466    69   33   4   1  1802     89
# ..    ...   ...  ...  ..  ..   ...    ...
# 635   596   103   12  12   1   983      0
# 636   716   123   14  16   2  1484      0
# 637  1055   101   66  41   1  2327    198
# 638   663   107   16  16   1  1469      0
# 639   964   103   73  27   1  2342    211
#
# [640 rows x 7 columns]

# %%
Y=pd.concat([Y,label],axis=1)

# %%
Y['label']=Y[0]

# %%
Y
# Out:
#                               음식    0  label
# 0     ('잡곡밥', '바지락조개국', '미나리나물')  272    272
# 1       ('잡곡밥', '바지락조개국', '취나물')  279    279
# 2      ('잡곡밥', '바지락조개국', '도토리묵')  271    271
# 3      ('잡곡밥', '바지락조개국', '새우구이')  274    274
# 4    ('잡곡밥', '바지락조개국', '숙주나물무침')  275    275
# ..                           ...  ...    ...
# 635   ('곤드레나물밥', '미역국', '애호박볶음')  107    107
# 636   ('곤드레나물밥', '미역국', '청포묵무침')  108    108
# 637    ('곤드레나물밥', '미역국', '병어구이')  103    103
# 638  ('곤드레나물밥', '미역국', '쑥갓나물무침')  106    106
# 639    ('곤드레나물밥', '미역국', '도미구이')  100    100
#
# [640 rows x 3 columns]

# %%
Y.columns
# Out:
# Index(['음식', 0, 'label'], dtype='object')

# %%
Y = Y.drop(0, axis = 1)

# %%
Y['구간']=s

# %%
Y.to_csv('/content/drive/MyDrive/캡스톤/최종/diabetes_foodlabel.csv')

# %%
Y=Y.drop(['음식'],axis=1)

# %%
Y=Y.drop(['label'],axis=1)

# %%
import numpy as np

# %%
X
# Out:
#      탄수화물  단백질  지방  당류  나트륨  콜레스테롤
# 0      70   33   5   1    1      0
# 1      71   33  10   1    1      0
# 2      78   32   4   1    1      0
# 3      73   74  11   1    2      0
# 4      69   33   4   1    1      0
# ..    ...  ...  ..  ..  ...    ...
# 635   103   12  12   1    0      0
# 636   123   14  16   2    1      0
# 637   101   66  41   1    2      0
# 638   107   16  16   1    1      0
# 639   103   73  27   1    2      0
#
# [640 rows x 6 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=42)

# %%
print(s.count(1))
print(s.count(2))
print(s.count(3))
print(s.count(4))
print(s.count(5))
print(s.count(6))
print(s.count(7))
print(s.count(8))
print(s.count(9))
print(s.count(10))
print(s.count(11))
print(s.count(12))
print(s.count(13))
print(s.count(14))
print(s.count(15))
print(s.count(16))
print(s.count(17))
# Out:
# 34
# 32
# 32
# 67
# 60
# 33
# 43
# 56
# 37
# 39
# 28
# 29
# 21
# 26
# 28
# 25
# 24

# %%
Y
# Out:
#      구간
# 0     6
# 1     7
# 2     6
# 3    16
# 4     5
# ..   ..
# 635  11
# 636  16
# 637  23
# 638  14
# 639  23
#
# [640 rows x 1 columns]

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(random_state=777)

clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_pred)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   after removing the cwd from sys.path.
# 0.8854166666666666

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score

from sklearn.model_selection import train_test_split

np.random.seed(777)

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=777)

param_grid = {
    'max_depth': [25, 30, 40, 45, 50],
    'n_estimators': [20, 50, 100, 150],
    'min_samples_split': [0.005, 0.05, 0.1],
}

clf = RandomForestClassifier(random_state=777, class_weight="balanced")

grid = GridSearchCV(clf, param_grid=param_grid, cv=3, refit=True)

grid.fit(X_train, y_train)


estimator = grid.best_estimator_
pred_labels = estimator.predict(X_test)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# ...

# %%
print('GridSearchCV best parameters:', grid.best_params_)
print('GridSearchCV best acc: {0:.2f}'.format(grid.best_score_))

print('Accuracy test : %.2f' % accuracy_score(y_test, pred_labels))
# Out:
# GridSearchCV best parameters: {'max_depth': 25, 'min_samples_split': 0.005, 'n_estimators': 150}
# GridSearchCV best acc: 0.82
# Accuracy test : 0.89

# %%
(2*0.7156*0.8969)/(0.8969+0.7156)
# Out:
# 0.7960578480620156

# %%
print('GridSearchCV best parameters:', grid.best_params_)
print('GridSearchCV best acc: {0:.2f}'.format(grid.best_score_))

print('Accuracy test : %.2f' % accuracy_score(y_test, pred_labels))
# Out:
# GridSearchCV best parameters: {'max_depth': 25, 'min_samples_split': 0.005, 'n_estimators': 150}
# GridSearchCV best acc: 0.82
# Accuracy test : 0.89

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train=scaler.fit_transform(X_train)
X_test=scaler.transform(X_test)

# %%
import joblib
joblib.dump(estimator, '/content/drive/MyDrive/캡스톤/최종/diabetes.pkl')
# Out:
# ['/content/drive/MyDrive/캡스톤/최종/diabetes.pkl']

# %% [markdown]
# ## 나트륨 관련 질병
#
# 고혈압 / 고혈압으로 인한 심장병 / 만성 신장병 / 뇌경색 / 위암 / 비만

# %%
data=pd.read_csv('/content/drive/MyDrive/캡스톤/최종/나트륨식단.csv')

# %%
data.head()
# Out:
#                            음식   열량  탄수화물  단백질  지방  당류  나트륨  콜레스테롤
# 0      ('기장밥', '사과', '과일샐러드')  521    98    7   9  13   49      5
# 1      ('기장밥', '사과', '마늘쫑무침')  414    89    6   2   2   95      0
# 2       ('기장밥', '사과', '두부조림')  454    88   10   5   1   82      0
# 3     ('기장밥', '사과', '건취나물무침')  427    89    7   3   0   68      0
# 4  ('기장밥', '사과', '고구마줄기나물무침')  424    88    6   4   0   91      0

# %%
X = data.drop('음식', axis = 1)
Y= data.drop(['열량','탄수화물','단백질','지방','당류','나트륨','콜레스테롤'],axis=1)

# %%
Y
# Out:
#                              음식
# 0        ('기장밥', '사과', '과일샐러드')
# 1        ('기장밥', '사과', '마늘쫑무침')
# 2         ('기장밥', '사과', '두부조림')
# 3       ('기장밥', '사과', '건취나물무침')
# 4    ('기장밥', '사과', '고구마줄기나물무침')
# ..                          ...
# 534     ('현미밥', '찐감자', '달걀프라이')
# 535   ('현미밥', '찐감자', '닭가슴살샐러드')
# 536     ('현미밥', '찐감자', '고구마맛탕')
# 537     ('현미밥', '찐감자', '채소샐러드')
# 538     ('현미밥', '찐감자', '쇠고기수육')
#
# [539 rows x 1 columns]

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
Y = le.fit_transform(Y['음식'])
label=Y
label=pd.DataFrame([label])
label=label.transpose()

# %%
data=pd.read_csv('/content/drive/MyDrive/캡스톤/최종/나트륨식단.csv')

# %%
print(np.unique(data['열량']))
data=data.rename(columns={'열량':'열량(kcal)'})
# Out:
# [ 378  381  387  388  390  391  397  398  400  401  404  405  407  408
#   413  414  415  416  417  418  421  423  424  426  427  428  430  431
#   433  434  436  437  440  441  443  444  445  448  451  453  454  456
#   458  461  463  464  466  470  471  479  480  481  482  485  488  489
#   491  492  493  494  495  496  497  498  499  501  502  504  505  506
#   507  508  509  511  512  514  515  516  517  519  520  521  522  523
#   524  525  528  529  530  531  532  534  535  536  537  538  541  542
#   546  548  549  550  552  555  557  559  560  563  567  570  572  573
#   575  576  577  578  579  580  581  582  584  585  586  587  588  589
#   591  592  593  594  595  596  597  598  599  600  601  602  603  604
#   605  606  607  608  609  612  613  614  615  616  617  618  619  620
#   621  622  624  625  626  627  631  632  634  642  644  649  650  651
#   653  654  657  660  661  663  664  666  667  668  671  673  674  680
# ...

# %%
s=[]
for i in range(len(data)):
  if data['열량(kcal)'][i] < 420:
    s.append(1)
  elif data['열량(kcal)'][i] < 450:
    s.append(2)
  elif data['열량(kcal)'][i] < 490:
    s.append(3)
  elif data['열량(kcal)'][i] < 505:
    s.append(4)
  elif data['열량(kcal)'][i] < 530:
    s.append(5)
  elif data['열량(kcal)'][i] < 570:
    s.append(6)
  elif data['열량(kcal)'][i] < 600:
    s.append(7)
  elif data['열량(kcal)'][i] < 650:
    s.append(8)
  elif data['열량(kcal)'][i] < 700:
    s.append(9)
  elif data['열량(kcal)'][i] < 850:
    s.append(10)
  elif data['열량(kcal)'][i] < 900:
    s.append(11)
  elif data['열량(kcal)'][i] < 970:
    s.append(12)
  else:
    s.append(13)

# %%
data['구간']=s

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.countplot(x="구간", data=data)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44396 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44036 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 44396 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 44036 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
for i in range(len(data)):
  data['나트륨'][i] = round(data['나트륨'][i]/1000,2)

for i in range(len(data)):
  try:
    data['콜레스테롤'][i]=round(data['콜레스테롤'][i]/1000,2)
  except:
    data['콜레스테롤'][i]=0
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
X = data.drop(['음식','구간'], axis = 1)
Y= data.drop(['열량(kcal)','탄수화물','단백질','지방','당류','나트륨','콜레스테롤'],axis=1)

# %%
label
# Out:
#        0
# 0    168
# 1    172
# 2    171
# 3    165
# 4    167
# ..   ...
# 534  444
# 535  445
# 536  441
# 537  450
# 538  448
#
# [539 rows x 1 columns]

# %%
Y=pd.concat([Y,label],axis=1)

# %%
Y['label']=Y[0]

# %%
Y
# Out:
#                              음식  구간    0  label
# 0        ('기장밥', '사과', '과일샐러드')   5  168    168
# 1        ('기장밥', '사과', '마늘쫑무침')   1  172    172
# 2         ('기장밥', '사과', '두부조림')   3  171    171
# 3       ('기장밥', '사과', '건취나물무침')   2  165    165
# 4    ('기장밥', '사과', '고구마줄기나물무침')   2  167    167
# ..                          ...  ..  ...    ...
# 534     ('현미밥', '찐감자', '달걀프라이')   9  444    444
# 535   ('현미밥', '찐감자', '닭가슴살샐러드')  10  445    445
# 536     ('현미밥', '찐감자', '고구마맛탕')  13  441    441
# 537     ('현미밥', '찐감자', '채소샐러드')  10  450    450
# 538     ('현미밥', '찐감자', '쇠고기수육')  13  448    448
#
# [539 rows x 4 columns]

# %%
Y.columns
# Out:
# Index(['음식', '구간', 0, 'label'], dtype='object')

# %%
Y = Y.drop(0, axis = 1)

# %%
Y['구간']=s

# %%
Y
# Out:
#                              음식  구간  label
# 0        ('기장밥', '사과', '과일샐러드')   5    168
# 1        ('기장밥', '사과', '마늘쫑무침')   1    172
# 2         ('기장밥', '사과', '두부조림')   3    171
# 3       ('기장밥', '사과', '건취나물무침')   2    165
# 4    ('기장밥', '사과', '고구마줄기나물무침')   2    167
# ..                          ...  ..    ...
# 534     ('현미밥', '찐감자', '달걀프라이')   9    444
# 535   ('현미밥', '찐감자', '닭가슴살샐러드')  10    445
# 536     ('현미밥', '찐감자', '고구마맛탕')  13    441
# 537     ('현미밥', '찐감자', '채소샐러드')  10    450
# 538     ('현미밥', '찐감자', '쇠고기수육')  13    448
#
# [539 rows x 3 columns]

# %%
Y.to_csv('/content/drive/MyDrive/캡스톤/최종/salt_foodlabel.csv')

# %%
Y=Y.drop(['음식'],axis=1)

# %%
Y=Y.drop(['label'],axis=1)

# %%
import numpy as np

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=42)

from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(random_state=777)

clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_pred)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   import sys
# 0.8888888888888888

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score

from sklearn.model_selection import train_test_split

np.random.seed(777)

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=777)

param_grid = {
    'max_depth': [25, 30, 40, 45, 50],
    'n_estimators': [20, 50, 100, 150],
    'min_samples_split': [0.005, 0.01, 0.05, 0.1],
}

clf = RandomForestClassifier(random_state=777, class_weight="balanced")

grid = GridSearchCV(clf, param_grid=param_grid, cv=3, refit=True)

grid.fit(X_train, y_train)


estimator = grid.best_estimator_
pred_labels = estimator.predict(X_test)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# ...

# %%
print('GridSearchCV best parameters:', grid.best_params_)
print('GridSearchCV best acc: {0:.2f}'.format(grid.best_score_))

print('Accuracy test : %.2f' % accuracy_score(y_test, pred_labels))
# Out:
# GridSearchCV best parameters: {'max_depth': 25, 'min_samples_split': 0.01, 'n_estimators': 150}
# GridSearchCV best acc: 0.89
# Accuracy test : 0.95

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=42)

from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(random_state=777)

clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)
mse = np.sqrt(mean_squared_error(y_pred, y_test))

print('평균제곱근오차 : ', mse)

from sklearn.metrics import r2_score
print('회귀 r2_score : ', r2_score(y_test,y_pred))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   import sys
# 평균제곱근오차 :  150.67264819329435
# 회귀 r2_score :  0.04507895116624605

# %%
import joblib
joblib.dump(estimator, '/content/drive/MyDrive/캡스톤/최종/salt.pkl')
# Out:
# ['/content/drive/MyDrive/캡스톤/최종/salt.pkl']

# %%
int(1.6*1.6*21)
# Out:
# 53

# %% [markdown]
# # 모델객체화

# %%
import pandas as pd
import joblib
import random
import numpy as np

class Diet:
    def __init__(self):
        '''
        __init__() : 초기화 함수
                    필요한 모델,라벨 불러오기
        '''

        self.model = joblib.load('/content/drive/MyDrive/캡스톤/최종/cholesterol.pkl')
        self.label = pd.read_csv('/content/drive/MyDrive/캡스톤/최종/chol_foodlabel.csv')
       
    def input(self,height,weight,age,sex,practice):
        self.data_dic={}

        self.data_dic['height']= height
        self.data_dic['weight'] = weight
        self.data_dic['age'] = age
        self.data_dic['sex'] = sex

        normal_weight = int((height/100)*(height/100)*21)
        want_weight = normal_weight 

        self.data_dic['want_weight'] = want_weight
        self.data_dic['want_time'] = 30
        self.data_dic['practice'] = practice


    def rec(self):
        '''
            rec() :
                1. 목표체중(w_w), 목표기간(w_t) => 일 목표 소모 열량 (m_cal) 생성
                2. 비만도 측정, 분류
                3. 기초대사량 측정
                4. 하루 필요 열량 분석
                5. 총 열량, 탄,단,지 구하기
                6. 모델 예측
                7. 결과
        '''

        #1. 목표체중 : 표준 체중, 목표기간(w_t) => 일 목표 소모 열량 (m_cal) 생성
        if self.data_dic['weight']>self.data_dic['want_weight']:
            m_w=self.data_dic['weight']-self.data_dic['want_weight']
        else:
            m_w=self.data_dic['want_weight']-self.data_dic['weight']

        cal=m_w*7200
        m_cal=round(cal/self.data_dic['want_time'],2)

       
        #3. 기초대사량 측정

        if self.data_dic['sex']==0: #남
            BMR = 66.47 + (13.75 * self.data_dic['weight']) + (5 * self.data_dic['height']) - (6.76 * self.data_dic['age'])
        else: #여
            BMR = 655.1 + (9.56 * self.data_dic['weight']) + (1.85 * self.data_dic['height']) - (4.68 * self.data_dic['age'])
            BMR = round(BMR,1)

        #운동
        p_dcal=round(m_cal*0.5,2)

        #식사
        f_dcal=round(m_cal*0.5,2)

        #4. 하루 필요 열량
        if self.data_dic['practice']==1:
            d_cal = BMR * 1.2
        elif self.data_dic['practice']==2:
            d_cal = BMR * 1.375
        elif self.data_dic['practice']==3:
            d_cal = BMR * 1.55
        elif self.data_dic['practice']==4:
            d_cal = BMR * 1.725
        else:
            d_cal = BMR * 1.9


        #5. 총 열량, 탄,단,지 

        if self.data_dic['weight']>self.data_dic['want_weight']:
            #다이어트 시 열량
            today_cal=(d_cal - f_dcal)*0.4
        else:
            #몸무게 증량 시 열량
            today_cal=(d_cal + f_dcal)*0.4
        
        self.cal = today_cal
        self.tan = today_cal*0.5
        self.dan = today_cal*0.2
        self.ji = today_cal*0.3
        self.dan = 0
        self.na = 0
        self.cho = 0
    
        test={
            '열량': self.cal,
            '탄수화물': self.tan,
            '단백질': self.dan,
            '지방': self.ji,
            '당류': self.dan,
            '나트륨': self.na,
            '콜레스테롤': self.cho
        }

        test=pd.DataFrame([test])
        
        #6. 모델예측
        y=self.model.predict([test.iloc[0]])

        #7. 결과
        self.practice_cal = p_dcal
        self.food_cal = f_dcal

        food_list = self.label['음식'][np.where(self.label['구간'] == y[0])[0]]
        cnt = random.randint(0, len(food_list)) 
        
        self.result = food_list.iloc[cnt]

# %%
diet= Diet()
diet.input(160,60,40,1,1)
diet.rec()
# Out:
# ('수수밥', '미소된장국', '도토리묵')
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   "X does not have valid feature names, but"

# %%
import pandas as pd
import joblib
import numpy as np

class Diet:
    def __init__(self):
        '''
        __init__() : 초기화 함수
                    필요한 모델,라벨 불러오기
        '''

        self.model = joblib.load('/content/drive/MyDrive/캡스톤/최종/diabetes.pkl')
        self.label = pd.read_csv('/content/drive/MyDrive/캡스톤/최종/diabetes_foodlabel.csv')
       
    def input(self,height,weight,age,sex,practice):
        self.data_dic={}

        self.data_dic['height']= height
        self.data_dic['weight'] = weight
        self.data_dic['age'] = age
        self.data_dic['sex'] = sex

        normal_weight = int((height/100)*(height/100)*21)
        want_weight = normal_weight 

        self.data_dic['want_weight'] = want_weight
        self.data_dic['want_time'] = 30
        self.data_dic['practice'] = practice


    def rec(self):
        '''
            rec() :
                1. 목표체중(w_w), 목표기간(w_t) => 일 목표 소모 열량 (m_cal) 생성
                2. 비만도 측정, 분류
                3. 기초대사량 측정
                4. 하루 필요 열량 분석
                5. 총 열량, 탄,단,지 구하기
                6. 모델 예측
                7. 결과
        '''

        #1. 목표체중 : 표준 체중, 목표기간(w_t) => 일 목표 소모 열량 (m_cal) 생성
        if self.data_dic['weight']>self.data_dic['want_weight']:
            m_w=self.data_dic['weight']-self.data_dic['want_weight']
        else:
            m_w=self.data_dic['want_weight']-self.data_dic['weight']

        cal=m_w*7200
        m_cal=round(cal/self.data_dic['want_time'],2)

       
        #3. 기초대사량 측정

        if self.data_dic['sex']==0: #남
            BMR = 66.47 + (13.75 * self.data_dic['weight']) + (5 * self.data_dic['height']) - (6.76 * self.data_dic['age'])
        else: #여
            BMR = 655.1 + (9.56 * self.data_dic['weight']) + (1.85 * self.data_dic['height']) - (4.68 * self.data_dic['age'])
            BMR = round(BMR,1)

        #운동
        p_dcal=round(m_cal*0.5,2)

        #식사
        f_dcal=round(m_cal*0.5,2)

        #4. 하루 필요 열량
        if self.data_dic['practice']==1:
            d_cal = BMR * 1.2
        elif self.data_dic['practice']==2:
            d_cal = BMR * 1.375
        elif self.data_dic['practice']==3:
            d_cal = BMR * 1.55
        elif self.data_dic['practice']==4:
            d_cal = BMR * 1.725
        else:
            d_cal = BMR * 1.9


        #5. 총 열량, 탄,단,지 

        if self.data_dic['weight']>self.data_dic['want_weight']:
            #다이어트 시 열량
            today_cal=(d_cal - f_dcal)*0.4
        else:
            #몸무게 증량 시 열량
            today_cal=(d_cal + f_dcal)*0.4
        
        self.cal = today_cal
        self.tan = today_cal*0.5
        self.dan = today_cal*0.2
        self.ji = today_cal*0.3
        self.dan = 0
        self.na = 0
        self.cho = 0
    
        test={
            '열량': self.cal,
            '탄수화물': self.tan,
            '단백질': self.dan,
            '지방': self.ji,
            '당류': self.dan,
            '나트륨': self.na,
            '콜레스테롤': self.cho
        }

        test=pd.DataFrame([test])
        
        #6. 모델예측
        y=self.model.predict([test.iloc[0]])

        #7. 결과
        self.practice_cal = p_dcal
        self.food_cal = f_dcal

        food_list = self.label['음식'][np.where(self.label['구간'] == y[0])[0]]
        cnt = random.randint(0, len(food_list)) 
        
        self.result = food_list.iloc[cnt]

        print(self.result)

# %%
diet= Diet()
diet.input(160,60,40,1,1)
diet.rec()
# Out:
# ('완두콩밥', '미역국', '도토리묵')
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   "X does not have valid feature names, but"

# %%
import pandas as pd
import joblib
import random
import numpy as np

class saltdiet:
    def __init__(self):
        '''
        __init__() : 초기화 함수
                    필요한 모델,라벨 불러오기
        '''

        self.model = joblib.load('/content/drive/MyDrive/캡스톤/최종/salt.pkl')
        self.label = pd.read_csv('/content/drive/MyDrive/캡스톤/최종/salt_foodlabel.csv')
       
    def input(self,height,weight,age,sex,practice):
        self.data_dic={}

        self.data_dic['height']= height
        self.data_dic['weight'] = weight
        self.data_dic['age'] = age
        self.data_dic['sex'] = sex

        normal_weight = int((height/100)*(height/100)*21)
        want_weight = normal_weight 

        self.data_dic['want_weight'] = want_weight
        self.data_dic['want_time'] = 30
        self.data_dic['practice'] = practice


    def rec(self):
      
        if self.data_dic['weight']>self.data_dic['want_weight']:
            m_w=self.data_dic['weight']-self.data_dic['want_weight']
        else:
            m_w=self.data_dic['want_weight']-self.data_dic['weight']

        cal=m_w*7200
        m_cal=round(cal/self.data_dic['want_time'],2)

       
        if self.data_dic['sex']==0: #남
            BMR = 66.47 + (13.75 * self.data_dic['weight']) + (5 * self.data_dic['height']) - (6.76 * self.data_dic['age'])
        else: #여
            BMR = 655.1 + (9.56 * self.data_dic['weight']) + (1.85 * self.data_dic['height']) - (4.68 * self.data_dic['age'])
            BMR = round(BMR,1)

        #운동
        p_dcal=round(m_cal*0.5,2)

        #식사
        f_dcal=round(m_cal*0.5,2)

        if self.data_dic['practice']==1:
            d_cal = BMR * 1.2
        elif self.data_dic['practice']==2:
            d_cal = BMR * 1.375
        elif self.data_dic['practice']==3:
            d_cal = BMR * 1.55
        elif self.data_dic['practice']==4:
            d_cal = BMR * 1.725
        else:
            d_cal = BMR * 1.9


        if self.data_dic['weight']>self.data_dic['want_weight']:
            #다이어트 시 열량
            today_cal=(d_cal - f_dcal)*0.4
        else:
            #몸무게 증량 시 열량
            today_cal=(d_cal + f_dcal)*0.4
        
        self.cal = today_cal
        self.tan = today_cal*0.5
        self.dan = today_cal*0.2
        self.ji = today_cal*0.3
        self.dan = 0
        self.na = 0
        self.cho = 0
    
        test={
            '열량': self.cal,
            '탄수화물': self.tan,
            '단백질': self.dan,
            '지방': self.ji,
            '당류': self.dan,
            '나트륨': self.na,
            '콜레스테롤': self.cho
        }

        test=pd.DataFrame([test])
        
        y=self.model.predict([test.iloc[0]])

        #결과
        self.practice_cal = p_dcal
        self.food_cal = f_dcal

        food_list = self.label['음식'][np.where(self.label['구간'] == y[0])[0]]
        cnt = random.randint(0, len(food_list)) 
        
        self.result = food_list.iloc[cnt]

        print(self.result)

# %%
diet= saltdiet()
diet.input(160,60,40,1,1)
diet.rec()
# Out:
# ('보리밥', '사과', '고구마줄기나물무침')
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   "X does not have valid feature names, but"
