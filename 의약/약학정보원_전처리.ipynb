# %%
import pandas as pd

# %%
from google.colab import drive 
drive.mount('/content/gdrive/')
# Out:
# Mounted at /content/gdrive/

# %%
before = pd.read_excel('/content/gdrive/MyDrive/캡스톤/coco/약학정보원_20220317_042445 (version 2).xlsx')
before
# Out:
#        Unnamed: 0                                                제품명  \
# 0               0                                 세르복스캡슐 Cerbox Cap.
# 1               1                                   셀몬캡슐 Celmon Cap.
# 2               2                         스모닌캅셀(수출용) Smonin Capsules
# 3               3                                        아모닌캡슐(수출용)
# 4               4                                 에버닌주 Eburnine Inj.
# ...           ...                                                ...
# 53105       53105                                  함소아방풍통성산엑스과립 None
# 53106       53106                                  파나실린정(배농산급탕건조엑스)
# 53107       53107                              함소아형방지황탕엑스과립(동의수세보원)
# 53108       53108  허브렉신캡슐(은교산건조엑스) Hurbrexin Cap.(EungyosanDried ...
# 53109       53109     크라시에의이인탕엑스세립 Kracie Euiiintang Ext. Fine Gran.
#
#                                                     보관방법  \
# 0                                                   밀폐용기
# ...

# %%
before['사용상의 주의사항'].unique()
# Out:
# array(['[허가사항변경(2014년 재평가), 의약품안전평가과-943, 2016.02.23.]_x000D_\n_x000D_\n(캡슐제)_x000D_\n■ 다음 환자에게 사용하지 말 것_x000D_\n 1) 이 약 또는 이 약의 구성성분에 과민반응 환자_x000D_\n 2) 두개내압이 상승된 뇌종양 환자_x000D_\n 3) 중증의 간·신장애 환자_x000D_\n 4) 임부 또는 임신하고 있을 가능성이 있는 여성_x000D_\n_x000D_\n2. 이상반응_x000D_\n  구역, 구토, 설사가 나타날 수 있다._x000D_\n_x000D_\n3. 임상검사치에의 영향_x000D_\n  각종 요검사시에 혈당의 검출을 방해할 수 있다. ',
#        '[허가사항변경(2014년 재평가), 의약품안전평가과-2589, 2015.11.17]_x000D_\n_x000D_\n(캡슐제)_x000D_\n■ 다음 환자에게 사용하지 말 것_x000D_\n1) 이 약에 과민반응 환자_x000D_\n2) 두개내압이 상승된 뇌종양 환자_x000D_\n3) 중증의 간·신장애 환자_x000D_\n4) 임부 또는 임신하고 있을 가능성이 있는 여성_x000D_\n_x000D_\n2. 이상반응_x000D_\n 구역, 구토, 설사가 나타날 수 있다._x000D_\n_x000D_\n3. 임상검사치에의 영향_x000D_\n  각종 요검사시에 혈당의 검출을 방해할 수 있다.',
#        '■ 다음 환자에게 사용하지 말 것_x000D_\n1) 구성성분에 과민증 환자_x000D_\n2) 두개내압이 상승된 뇌종양 환자_x000D_\n3) 중증의 간·신장애 환자_x000D_\n4) 임부 또는 임신하고 있을 가능성이 있는 부인_x000D_\n_x000D_\n2. 부작용_x000D_\n구역, 구토, 설사가 나타날 수 있다._x000D_\n_x000D_\n3. 임상검사치에의 영향_x000D_\n각종 요검사시에 혈당의 검출을 방해할 수 있다. _x000D_\n  _x000D_\n',
# ...

# %% [markdown]
# ## Version2

# %%
after = pd.read_excel('/content/gdrive/MyDrive/캡스톤/coco/약학정보원_20220317_042445 (version 2).xlsx')

# %%
after
# Out:
#        Unnamed: 0                                                제품명  \
# 0               0                                 세르복스캡슐 Cerbox Cap.
# 1               1                                   셀몬캡슐 Celmon Cap.
# 2               2                         스모닌캅셀(수출용) Smonin Capsules
# 3               3                                        아모닌캡슐(수출용)
# 4               4                                 에버닌주 Eburnine Inj.
# ...           ...                                                ...
# 53105       53105                                  함소아방풍통성산엑스과립 None
# 53106       53106                                  파나실린정(배농산급탕건조엑스)
# 53107       53107                              함소아형방지황탕엑스과립(동의수세보원)
# 53108       53108  허브렉신캡슐(은교산건조엑스) Hurbrexin Cap.(EungyosanDried ...
# 53109       53109     크라시에의이인탕엑스세립 Kracie Euiiintang Ext. Fine Gran.
#
#                                                     보관방법  \
# 0                                                   밀폐용기
# ...

# %%
after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('1. 소아에 대한 투여','■ 소아에 대한 투여')
after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('2. 소아에 대한 투여','■ 소아에 대한 투여')
after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('3. 소아에 대한 투여','■ 소아에 대한 투여')
after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('4. 소아에 대한 투여','■ 소아에 대한 투여')
after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('5. 소아에 대한 투여','■ 소아에 대한 투여')
after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('6. 소아에 대한 투여','■ 소아에 대한 투여')
after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('7. 소아에 대한 투여','■ 소아에 대한 투여')

after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('3. 고령자에 대한 투여','■ 고령자에 대한 투여')
after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('4. 고령자에 대한 투여','■ 고령자에 대한 투여')
after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('5. 고령자에 대한 투여','■ 고령자에 대한 투여')
after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('6. 고령자에 대한 투여','■ 고령자에 대한 투여')
after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('7. 고령자에 대한 투여','■ 고령자에 대한 투여')
after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('8. 고령자에 대한 투여','■ 고령자에 대한 투여')
after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('9. 고령자에 대한 투여','■ 고령자에 대한 투여')


after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('3. 소아','■ 소아에 대한 투여')
after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('4. 소아','■ 소아에 대한 투여')
after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('5. 소아','■ 소아에 대한 투여')
after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('6. 소아','■ 소아에 대한 투여')
after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('7. 소아','■ 소아에 대한 투여')
after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('8. 소아','■ 소아에 대한 투여')
after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('9. 소아','■ 소아에 대한 투여')


after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('임부 및 수유부','임부 및 수유부에 대한 투여')


after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('1. 임부 및 수유부에 대한 투여','■ 임부 및 수유부에 대한 투여')
after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('2. 임부 및 수유부에 대한 투여','■ 임부 및 수유부에 대한 투여')
after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('3. 임부 및 수유부에 대한 투여','■ 임부 및 수유부에 대한 투여')
after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('4. 임부 및 수유부에 대한 투여','■ 임부 및 수유부에 대한 투여')
after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('5. 임부 및 수유부에 대한 투여','■ 임부 및 수유부에 대한 투여')
after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('6. 임부 및 수유부에 대한 투여','■ 임부 및 수유부에 대한 투여')
after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('7. 임부 및 수유부에 대한 투여','■ 임부 및 수유부에 대한 투여')
after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('8. 임부 및 수유부에 대한 투여','■ 임부 및 수유부에 대한 투여')
after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('9. 임부 및 수유부에 대한 투여','■ 임부 및 수유부에 대한 투여')


after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('기타주의사항','기타')


after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('3. 기타','■ 기타')
after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('4. 기타','■ 기타')
after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('5. 기타','■ 기타')
after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('6. 기타','■ 기타')
after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('7. 기타','■ 기타')
after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('8. 기타','■ 기타')
after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('9. 기타','■ 기타')
after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('10. 기타','■ 기타')
after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('11. 기타','■ 기타')


after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('1. 부작용','■ 부작용')
after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('2. 부작용','■ 부작용')
after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('3. 부작용','■ 부작용')
after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('4. 부작용','■ 부작용')
after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('5. 부작용','■ 부작용')
after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('6. 부작용','■ 부작용')
after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('7. 부작용','■ 부작용')
after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('8. 부작용','■ 부작용')

after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('1. 경고','■ 경고')
after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('2. 경고','■ 경고')
after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('3. 경고','■ 경고')
after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('4. 경고','■ 경고')
after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('5. 경고','■ 경고')
after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('6. 경고','■ 경고')
after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('7. 경고','■ 경고')
after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('8. 경고','■ 경고')
after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('9. 경고','■ 경고')


after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('1. 다음 환자에는 신중히 투여할 것.','■ 다음 환자에는 신중히 투여할 것')
after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('2. 다음 환자에는 신중히 투여할 것.','■ 다음 환자에는 신중히 투여할 것')
after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('3. 다음 환자에는 신중히 투여할 것.','■ 다음 환자에는 신중히 투여할 것')
after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('4. 다음 환자에는 신중히 투여할 것.','■ 다음 환자에는 신중히 투여할 것')
after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('5. 다음 환자에는 신중히 투여할 것.','■ 다음 환자에는 신중히 투여할 것')
after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('6. 다음 환자에는 신중히 투여할 것.','■ 다음 환자에는 신중히 투여할 것')
after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('7. 다음 환자에는 신중히 투여할 것.','■ 다음 환자에는 신중히 투여할 것')
after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('8. 다음 환자에는 신중히 투여할 것.','■ 다음 환자에는 신중히 투여할 것')
after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('9. 다음 환자에는 신중히 투여할 것.','■ 다음 환자에는 신중히 투여할 것')
after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('10. 다음 환자에는 신중히 투여할 것.','■ 다음 환자에는 신중히 투여할 것')
after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('11. 다음 환자에는 신중히 투여할 것.','■ 다음 환자에는 신중히 투여할 것')

after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('1. 다음 환자(경우)에는 투여하지 말 것.','■ 다음 환자(경우)에는 투여하지 말 것')
after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('2. 다음 환자(경우)에는 투여하지 말 것.','■ 다음 환자(경우)에는 투여하지 말 것')
after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('3. 다음 환자(경우)에는 투여하지 말 것.','■ 다음 환자(경우)에는 투여하지 말 것')
after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('4. 다음 환자(경우)에는 투여하지 말 것.','■ 다음 환자(경우)에는 투여하지 말 것')
after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('5. 다음 환자(경우)에는 투여하지 말 것.','■ 다음 환자(경우)에는 투여하지 말 것')
after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('6. 다음 환자(경우)에는 투여하지 말 것.','■ 다음 환자(경우)에는 투여하지 말 것')
after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('7. 다음 환자(경우)에는 투여하지 말 것.','■ 다음 환자(경우)에는 투여하지 말 것')
after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('8. 다음 환자(경우)에는 투여하지 말 것.','■ 다음 환자(경우)에는 투여하지 말 것')
after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('9. 다음 환자(경우)에는 투여하지 말 것.','■ 다음 환자(경우)에는 투여하지 말 것')
after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('10. 다음 환자(경우)에는 투여하지 말 것.','■ 다음 환자(경우)에는 투여하지 말 것')

after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('1. 보관 및 취급상의 주의사항','■ 보관 및 취급상의 주의사항')
after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('2. 보관 및 취급상의 주의사항','■ 보관 및 취급상의 주의사항')
after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('3. 보관 및 취급상의 주의사항','■ 보관 및 취급상의 주의사항')
after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('4. 보관 및 취급상의 주의사항','■ 보관 및 취급상의 주의사항')
after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('5. 보관 및 취급상의 주의사항','■ 보관 및 취급상의 주의사항')
after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('6. 보관 및 취급상의 주의사항','■ 보관 및 취급상의 주의사항')
after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('7. 보관 및 취급상의 주의사항','■ 보관 및 취급상의 주의사항')
after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('8. 보관 및 취급상의 주의사항','■ 보관 및 취급상의 주의사항')
after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('9. 보관 및 취급상의 주의사항','■ 보관 및 취급상의 주의사항')
after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('10. 보관 및 취급상의 주의사항','■ 보관 및 취급상의 주의사항')
after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('11. 보관 및 취급상의 주의사항','■ 보관 및 취급상의 주의사항')



after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('일반적인 주의','일반적 주의')

after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('1. 일반적 주의','■ 일반적 주의')
after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('2. 일반적 주의','■ 일반적 주의')
after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('3. 일반적 주의','■ 일반적 주의')
after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('4. 일반적 주의','■ 일반적 주의')
after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('5. 일반적 주의','■ 일반적 주의')
after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('6. 일반적 주의','■ 일반적 주의')
after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('7. 일반적 주의','■ 일반적 주의')
after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('8. 일반적 주의','■ 일반적 주의')

after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('1. 과량 투여시의 처치','■ 과량 투여시의 처치')
after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('2. 과량 투여시의 처치','■ 과량 투여시의 처치')
after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('3. 과량 투여시의 처치','■ 과량 투여시의 처치')
after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('4. 과량 투여시의 처치','■ 과량 투여시의 처치')
after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('5. 과량 투여시의 처치','■ 과량 투여시의 처치')
after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('6. 과량 투여시의 처치','■ 과량 투여시의 처치')
after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('7. 과량 투여시의 처치','■ 과량 투여시의 처치')
after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('8. 과량 투여시의 처치','■ 과량 투여시의 처치')
after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('9. 과량 투여시의 처치','■ 과량 투여시의 처치')
after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('10. 과량 투여시의 처치','■ 과량 투여시의 처치')
after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('11. 과량 투여시의 처치','■ 과량 투여시의 처치')
after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('12. 과량 투여시의 처치','■ 과량 투여시의 처치')
after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('13. 과량 투여시의 처치','■ 과량 투여시의 처치')

after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('상호작용','약물상호작용')

after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('1. 약물상호작용','■ 약물상호작용')
after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('2. 약물상호작용','■ 약물상호작용')
after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('3. 약물상호작용','■ 약물상호작용')
after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('4. 약물상호작용','■ 약물상호작용')
after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('5. 약물상호작용','■ 약물상호작용')
after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('6. 약물상호작용','■ 약물상호작용')
after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('7. 약물상호작용','■ 약물상호작용')

after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('3. 적용상의 주의','■ 적용상의 주의')
after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('4. 적용상의 주의','■ 적용상의 주의')
after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('5. 적용상의 주의','■ 적용상의 주의')
after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('6. 적용상의 주의','■ 적용상의 주의')
after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('7. 적용상의 주의','■ 적용상의 주의')
after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('8. 적용상의 주의','■ 적용상의 주의')
after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('9. 적용상의 주의','■ 적용상의 주의')
after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('10. 적용상의 주의','■ 적용상의 주의')
after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('11. 적용상의 주의','■ 적용상의 주의')
after['사용상의 주의사항'] = after['사용상의 주의사항'].str.replace('12. 적용상의 주의','■ 적용상의 주의')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   """
# ...

# %%
after
# Out:
#        Unnamed: 0                                                제품명  \
# 0               0                                 세르복스캡슐 Cerbox Cap.
# 1               1                                   셀몬캡슐 Celmon Cap.
# 2               2                         스모닌캅셀(수출용) Smonin Capsules
# 3               3                                        아모닌캡슐(수출용)
# 4               4                                 에버닌주 Eburnine Inj.
# ...           ...                                                ...
# 53105       53105                                  함소아방풍통성산엑스과립 None
# 53106       53106                                  파나실린정(배농산급탕건조엑스)
# 53107       53107                              함소아형방지황탕엑스과립(동의수세보원)
# 53108       53108  허브렉신캡슐(은교산건조엑스) Hurbrexin Cap.(EungyosanDried ...
# 53109       53109     크라시에의이인탕엑스세립 Kracie Euiiintang Ext. Fine Gran.
#
#                                                     보관방법  \
# 0                                                   밀폐용기
# ...

# %%
after.to_excel('/content/gdrive/MyDrive/캡스톤/coco/약학정보원_20220317_042445 (version 3).xlsx', index = False)

# %% [markdown]
# ## Version 3

# %%
after2 = pd.read_excel('/content/gdrive/MyDrive/캡스톤/coco/약학정보원_20220317_042445 (version 3).xlsx')
# Out:
# Exception ignored in: <function ZipFile.__del__ at 0x7f759a992ef0>
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/zipfile.py", line 1809, in __del__
#     self.close()
#   File "/usr/lib/python3.7/zipfile.py", line 1826, in close
#     self.fp.seek(self.start_dir)
# ValueError: seek of closed file

# %%
after2 = after2.drop('Unnamed: 0', axis = 1)
after2
# Out:
#                                                      제품명  \
# 0                                     세르복스캡슐 Cerbox Cap.
# 1                                       셀몬캡슐 Celmon Cap.
# 2                             스모닌캅셀(수출용) Smonin Capsules
# 3                                            아모닌캡슐(수출용)
# 4                                     에버닌주 Eburnine Inj.
# ...                                                  ...
# 53105                                  함소아방풍통성산엑스과립 None
# 53106                                  파나실린정(배농산급탕건조엑스)
# 53107                              함소아형방지황탕엑스과립(동의수세보원)
# 53108  허브렉신캡슐(은교산건조엑스) Hurbrexin Cap.(EungyosanDried ...
# 53109     크라시에의이인탕엑스세립 Kracie Euiiintang Ext. Fine Gran.
#
#                                                     보관방법  \
# 0                                                   밀폐용기
# 1                                             기밀용기. 실온보관
# 2                                              기밀용기,실온보관
# ...

# %%
after2['사용상의 주의사항'] = after2['사용상의 주의사항'].str.replace('2. 임상검사치에의 영향','■ 임상검사치에의 영향')
after2['사용상의 주의사항'] = after2['사용상의 주의사항'].str.replace('3. 임상검사치에의 영향','■ 임상검사치에의 영향')
after2['사용상의 주의사항'] = after2['사용상의 주의사항'].str.replace('4. 임상검사치에의 영향','■ 임상검사치에의 영향')
after2['사용상의 주의사항'] = after2['사용상의 주의사항'].str.replace('5. 임상검사치에의 영향','■ 임상검사치에의 영향')
after2['사용상의 주의사항'] = after2['사용상의 주의사항'].str.replace('6. 임상검사치에의 영향','■ 임상검사치에의 영향')
after2['사용상의 주의사항'] = after2['사용상의 주의사항'].str.replace('7. 임상검사치에의 영향','■ 임상검사치에의 영향')
after2['사용상의 주의사항'] = after2['사용상의 주의사항'].str.replace('8. 임상검사치에의 영향','■ 임상검사치에의 영향')

after2['사용상의 주의사항'] = after2['사용상의 주의사항'].str.replace('2. 임산부 및 수유부에 대한 투여','■ 임산부 및 수유부에 대한 투여')
after2['사용상의 주의사항'] = after2['사용상의 주의사항'].str.replace('3. 임산부 및 수유부에 대한 투여','■ 임산부 및 수유부에 대한 투여')
after2['사용상의 주의사항'] = after2['사용상의 주의사항'].str.replace('4. 임산부 및 수유부에 대한 투여','■ 임산부 및 수유부에 대한 투여')
after2['사용상의 주의사항'] = after2['사용상의 주의사항'].str.replace('5. 임산부 및 수유부에 대한 투여','■ 임산부 및 수유부에 대한 투여')
after2['사용상의 주의사항'] = after2['사용상의 주의사항'].str.replace('6. 임산부 및 수유부에 대한 투여','■ 임산부 및 수유부에 대한 투여')
after2['사용상의 주의사항'] = after2['사용상의 주의사항'].str.replace('7. 임산부 및 수유부에 대한 투여','■ 임산부 및 수유부에 대한 투여')

after2['사용상의 주의사항'] = after2['사용상의 주의사항'].str.replace('약물약물상호작용','약물상호작용')
#사용할 때 다음의 사항을 주의할 것.

after2['사용상의 주의사항'] = after2['사용상의 주의사항'].str.replace('1. 약물상호작용','■ 약물상호작용')
after2['사용상의 주의사항'] = after2['사용상의 주의사항'].str.replace('2. 약물상호작용','■ 약물상호작용')
after2['사용상의 주의사항'] = after2['사용상의 주의사항'].str.replace('3. 약물상호작용','■ 약물상호작용')
after2['사용상의 주의사항'] = after2['사용상의 주의사항'].str.replace('4. 약물상호작용','■ 약물상호작용')
after2['사용상의 주의사항'] = after2['사용상의 주의사항'].str.replace('5. 약물상호작용','■ 약물상호작용')
after2['사용상의 주의사항'] = after2['사용상의 주의사항'].str.replace('6. 약물상호작용','■ 약물상호작용')
after2['사용상의 주의사항'] = after2['사용상의 주의사항'].str.replace('7. 약물상호작용','■ 약물상호작용')

after2['사용상의 주의사항'] = after2['사용상의 주의사항'].str.replace('보관상의 주의사항','보관 및 취급상의 주의사항')
after2['사용상의 주의사항'] = after2['사용상의 주의사항'].str.replace('보관 및 취급상의 주의','보관 및 취급상의 주의사항')

after2['사용상의 주의사항'] = after2['사용상의 주의사항'].str.replace('1. 보관 및 취급상의 주의사항','■ 보관 및 취급상의 주의사항')
after2['사용상의 주의사항'] = after2['사용상의 주의사항'].str.replace('2. 보관 및 취급상의 주의사항','■ 보관 및 취급상의 주의사항')
after2['사용상의 주의사항'] = after2['사용상의 주의사항'].str.replace('3. 보관 및 취급상의 주의사항','■ 보관 및 취급상의 주의사항')
after2['사용상의 주의사항'] = after2['사용상의 주의사항'].str.replace('4. 보관 및 취급상의 주의사항','■ 보관 및 취급상의 주의사항')
after2['사용상의 주의사항'] = after2['사용상의 주의사항'].str.replace('5. 보관 및 취급상의 주의사항','■ 보관 및 취급상의 주의사항')
after2['사용상의 주의사항'] = after2['사용상의 주의사항'].str.replace('6. 보관 및 취급상의 주의사항','■ 보관 및 취급상의 주의사항')
after2['사용상의 주의사항'] = after2['사용상의 주의사항'].str.replace('7. 보관 및 취급상의 주의사항','■ 보관 및 취급상의 주의사항')
after2['사용상의 주의사항'] = after2['사용상의 주의사항'].str.replace('8. 보관 및 취급상의 주의사항','■ 보관 및 취급상의 주의사항')
after2['사용상의 주의사항'] = after2['사용상의 주의사항'].str.replace('9. 보관 및 취급상의 주의사항','■ 보관 및 취급상의 주의사항')

after2['사용상의 주의사항'] = after2['사용상의 주의사항'].str.replace('이 약은 다음의 신체 부위에는 사용하지 말 것','다음 부위에는 사용하지 말 것.')



after2['사용상의 주의사항'] = after2['사용상의 주의사항'].str.replace('1. 다인용 포장에 대한 용법 주의','■ 다인용 포장에 대한 용법 주의')
after2['사용상의 주의사항'] = after2['사용상의 주의사항'].str.replace('2. 다인용 포장에 대한 용법 주의','■ 다인용 포장에 대한 용법 주의')
after2['사용상의 주의사항'] = after2['사용상의 주의사항'].str.replace('3. 다인용 포장에 대한 용법 주의','■ 다인용 포장에 대한 용법 주의')
after2['사용상의 주의사항'] = after2['사용상의 주의사항'].str.replace('4. 다인용 포장에 대한 용법 주의','■ 다인용 포장에 대한 용법 주의')
after2['사용상의 주의사항'] = after2['사용상의 주의사항'].str.replace('5. 다인용 포장에 대한 용법 주의','■ 다인용 포장에 대한 용법 주의')
after2['사용상의 주의사항'] = after2['사용상의 주의사항'].str.replace('6. 다인용 포장에 대한 용법 주의','■ 다인용 포장에 대한 용법 주의')
after2['사용상의 주의사항'] = after2['사용상의 주의사항'].str.replace('7. 다인용 포장에 대한 용법 주의','■ 다인용 포장에 대한 용법 주의')
after2['사용상의 주의사항'] = after2['사용상의 주의사항'].str.replace('8. 다인용 포장에 대한 용법 주의','■ 다인용 포장에 대한 용법 주의')
after2['사용상의 주의사항'] = after2['사용상의 주의사항'].str.replace('9. 다인용 포장에 대한 용법 주의','■ 다인용 포장에 대한 용법 주의')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   """
# ...

# %%
after2.to_excel('/content/gdrive/MyDrive/캡스톤/coco/약학정보원_20220317_042445 (version 4).xlsx', index = False)

# %% [markdown]
# ## Version 4

# %%
after3 = pd.read_excel('/content/gdrive/MyDrive/캡스톤/coco/약학정보원_20220317_042445 (version 4).xlsx')

# %%
after3['사용상의 주의사항'] = after3['사용상의 주의사항'].str.replace('10. 다인용 포장에 대한 용법 주의','■ 다인용 포장에 대한 용법 주의')

after3['사용상의 주의사항'] = after3['사용상의 주의사항'].str.replace('1. 과량투여시의 처치','■ 과량투여시의 처치')
after3['사용상의 주의사항'] = after3['사용상의 주의사항'].str.replace('2. 과량투여시의 처치','■ 과량투여시의 처치')
after3['사용상의 주의사항'] = after3['사용상의 주의사항'].str.replace('3. 과량투여시의 처치','■ 과량투여시의 처치')
after3['사용상의 주의사항'] = after3['사용상의 주의사항'].str.replace('4. 과량투여시의 처치','■ 과량투여시의 처치')
after3['사용상의 주의사항'] = after3['사용상의 주의사항'].str.replace('5. 과량투여시의 처치','■ 과량투여시의 처치')
after3['사용상의 주의사항'] = after3['사용상의 주의사항'].str.replace('6. 과량투여시의 처치','■ 과량투여시의 처치')
after3['사용상의 주의사항'] = after3['사용상의 주의사항'].str.replace('7. 과량투여시의 처치','■ 과량투여시의 처치')
after3['사용상의 주의사항'] = after3['사용상의 주의사항'].str.replace('8. 과량투여시의 처치','■ 과량투여시의 처치')
after3['사용상의 주의사항'] = after3['사용상의 주의사항'].str.replace('9. 과량투여시의 처치','■ 과량투여시의 처치')
after3['사용상의 주의사항'] = after3['사용상의 주의사항'].str.replace('10. 과량투여시의 처치','■ 과량투여시의 처치')
after3['사용상의 주의사항'] = after3['사용상의 주의사항'].str.replace('11. 과량투여시의 처치','■ 과량투여시의 처치')
after3['사용상의 주의사항'] = after3['사용상의 주의사항'].str.replace('12. 과량투여시의 처치','■ 과량투여시의 처치')

after3['사용상의 주의사항'] = after3['사용상의 주의사항'].str.replace('다음의 환자는 사용전에 의사또는 약사와 상담할 것','다음과 같은 사람은 이 약을 사용하기 전에 의사, 약사와 상의할 것')
after3['사용상의 주의사항'] = after3['사용상의 주의사항'].str.replace('다음과 같은 사람은 이 약을 사용하기 전에 의사, 치과의사, 약사와 상의할 것.','다음과 같은 사람은 이 약을 사용하기 전에 의사, 약사와 상의할 것')
after3['사용상의 주의사항'] = after3['사용상의 주의사항'].str.replace('다음과 같은 사람은 이 약을 사용하기 전에 의사, 약사와 상의할 것.','다음과 같은 사람은 이 약을 사용하기 전에 의사, 약사와 상의할 것')
after3['사용상의 주의사항'] = after3['사용상의 주의사항'].str.replace('다음 부위에는 사용하지 말 것.','다음 부위에는 사용하지 말 것')

after3['사용상의 주의사항'] = after3['사용상의 주의사항'].str.replace('일반적주의.','일반적 주의')
after3['사용상의 주의사항'] = after3['사용상의 주의사항'].str.replace('1. 일반적 주의','■ 일반적 주의')
after3['사용상의 주의사항'] = after3['사용상의 주의사항'].str.replace('2. 일반적 주의','■ 일반적 주의')
after3['사용상의 주의사항'] = after3['사용상의 주의사항'].str.replace('3. 일반적 주의','■ 일반적 주의')
after3['사용상의 주의사항'] = after3['사용상의 주의사항'].str.replace('4. 일반적 주의','■ 일반적 주의')
after3['사용상의 주의사항'] = after3['사용상의 주의사항'].str.replace('5. 일반적 주의','■ 일반적 주의')
after3['사용상의 주의사항'] = after3['사용상의 주의사항'].str.replace('6. 일반적 주의','■ 일반적 주의')
after3['사용상의 주의사항'] = after3['사용상의 주의사항'].str.replace('7. 일반적 주의','■ 일반적 주의')
after3['사용상의 주의사항'] = after3['사용상의 주의사항'].str.replace('8. 일반적 주의','■ 일반적 주의')

after3['사용상의 주의사항'] = after3['사용상의 주의사항'].str.replace('1. 이상반응','■ 이상반응')
after3['사용상의 주의사항'] = after3['사용상의 주의사항'].str.replace('2. 이상반응','■ 이상반응')
after3['사용상의 주의사항'] = after3['사용상의 주의사항'].str.replace('3. 이상반응','■ 이상반응')
after3['사용상의 주의사항'] = after3['사용상의 주의사항'].str.replace('4. 이상반응','■ 이상반응')
after3['사용상의 주의사항'] = after3['사용상의 주의사항'].str.replace('5. 이상반응','■ 이상반응')
after3['사용상의 주의사항'] = after3['사용상의 주의사항'].str.replace('6. 이상반응','■ 이상반응')
after3['사용상의 주의사항'] = after3['사용상의 주의사항'].str.replace('7. 이상반응','■ 이상반응')

after3['사용상의 주의사항'] = after3['사용상의 주의사항'].str.replace('1. 다음 부위에는 사용하지 말 것','■ 다음 부위에는 사용하지 말 것')
after3['사용상의 주의사항'] = after3['사용상의 주의사항'].str.replace('2. 다음 부위에는 사용하지 말 것','■ 다음 부위에는 사용하지 말 것')
after3['사용상의 주의사항'] = after3['사용상의 주의사항'].str.replace('3. 다음 부위에는 사용하지 말 것','■ 다음 부위에는 사용하지 말 것')
after3['사용상의 주의사항'] = after3['사용상의 주의사항'].str.replace('4. 다음 부위에는 사용하지 말 것','■ 다음 부위에는 사용하지 말 것')
after3['사용상의 주의사항'] = after3['사용상의 주의사항'].str.replace('5. 다음 부위에는 사용하지 말 것','■ 다음 부위에는 사용하지 말 것')
after3['사용상의 주의사항'] = after3['사용상의 주의사항'].str.replace('6. 다음 부위에는 사용하지 말 것','■ 다음 부위에는 사용하지 말 것')
after3['사용상의 주의사항'] = after3['사용상의 주의사항'].str.replace('7. 다음 부위에는 사용하지 말 것','■ 다음 부위에는 사용하지 말 것')
after3['사용상의 주의사항'] = after3['사용상의 주의사항'].str.replace('8. 다음 부위에는 사용하지 말 것','■ 다음 부위에는 사용하지 말 것')

after3['사용상의 주의사항'] = after3['사용상의 주의사항'].str.replace('다음 환자에는 투여하지 말 것.', '다음 환자에게 사용하지 말 것')
after3['사용상의 주의사항'] = after3['사용상의 주의사항'].str.replace('다음 환자에는 투여하지 말 것', '다음 환자에게 사용하지 말 것')
after3['사용상의 주의사항'] = after3['사용상의 주의사항'].str.replace('다음과 같은 사람은 이 약을 복용하지 말 것.', '다음 환자에게 사용하지 말 것')
after3['사용상의 주의사항'] = after3['사용상의 주의사항'].str.replace('다음 사람은 복용하지 말 것.', '다음 환자에게 사용하지 말 것')
after3['사용상의 주의사항'] = after3['사용상의 주의사항'].str.replace('다음과 같은 사람은 이 약을 복용하지 마십시오', '다음 환자에게 사용하지 말 것')
after3['사용상의 주의사항'] = after3['사용상의 주의사항'].str.replace('다음과 같은 사람은 이 약을 사용하지 말 것', '다음 환자에게 사용하지 말 것')

after3['사용상의 주의사항'] = after3['사용상의 주의사항'].str.replace('1. 다음 환자에게 사용하지 말 것', '■ 다음 환자에게 사용하지 말 것')
after3['사용상의 주의사항'] = after3['사용상의 주의사항'].str.replace('2. 다음 환자에게 사용하지 말 것', '■ 다음 환자에게 사용하지 말 것')
after3['사용상의 주의사항'] = after3['사용상의 주의사항'].str.replace('3. 다음 환자에게 사용하지 말 것', '■ 다음 환자에게 사용하지 말 것')
after3['사용상의 주의사항'] = after3['사용상의 주의사항'].str.replace('4. 다음 환자에게 사용하지 말 것', '■ 다음 환자에게 사용하지 말 것')
after3['사용상의 주의사항'] = after3['사용상의 주의사항'].str.replace('5. 다음 환자에게 사용하지 말 것', '■ 다음 환자에게 사용하지 말 것')

after3['사용상의 주의사항'] = after3['사용상의 주의사항'].str.replace('1. 다음과 같은 사람은 이 약을 사용하기 전에 의사, 약사와 상의할 것','■ 다음과 같은 사람은 이 약을 사용하기 전에 의사, 약사와 상의할 것')
after3['사용상의 주의사항'] = after3['사용상의 주의사항'].str.replace('2. 다음과 같은 사람은 이 약을 사용하기 전에 의사, 약사와 상의할 것','■ 다음과 같은 사람은 이 약을 사용하기 전에 의사, 약사와 상의할 것')
after3['사용상의 주의사항'] = after3['사용상의 주의사항'].str.replace('3. 다음과 같은 사람은 이 약을 사용하기 전에 의사, 약사와 상의할 것','■ 다음과 같은 사람은 이 약을 사용하기 전에 의사, 약사와 상의할 것')
after3['사용상의 주의사항'] = after3['사용상의 주의사항'].str.replace('4. 다음과 같은 사람은 이 약을 사용하기 전에 의사, 약사와 상의할 것','■ 다음과 같은 사람은 이 약을 사용하기 전에 의사, 약사와 상의할 것')
after3['사용상의 주의사항'] = after3['사용상의 주의사항'].str.replace('5. 다음과 같은 사람은 이 약을 사용하기 전에 의사, 약사와 상의할 것','■ 다음과 같은 사람은 이 약을 사용하기 전에 의사, 약사와 상의할 것')
after3['사용상의 주의사항'] = after3['사용상의 주의사항'].str.replace('6. 다음과 같은 사람은 이 약을 사용하기 전에 의사, 약사와 상의할 것','■ 다음과 같은 사람은 이 약을 사용하기 전에 의사, 약사와 상의할 것')
after3['사용상의 주의사항'] = after3['사용상의 주의사항'].str.replace('7. 다음과 같은 사람은 이 약을 사용하기 전에 의사, 약사와 상의할 것','■ 다음과 같은 사람은 이 약을 사용하기 전에 의사, 약사와 상의할 것')
after3['사용상의 주의사항'] = after3['사용상의 주의사항'].str.replace('8. 다음과 같은 사람은 이 약을 사용하기 전에 의사, 약사와 상의할 것','■ 다음과 같은 사람은 이 약을 사용하기 전에 의사, 약사와 상의할 것')

after3['사용상의 주의사항'] = after3['사용상의 주의사항'].str.replace('주의사항사항','주의사항')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   """
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#
# ...

# %%
after3.to_excel('/content/gdrive/MyDrive/캡스톤/coco/약학정보원_20220317_042445 (version 5).xlsx', index = False)

# %% [markdown]
# ##Version 5

# %%
after4 = pd.read_excel('/content/gdrive/MyDrive/캡스톤/coco/약학정보원_20220317_042445 (version 5).xlsx')

# %%
import numpy as np
print(len(after4['사용상의 주의사항'].unique()))
# Out:
# 41234

# %%
after4['사용상의 주의사항'] = after4['사용상의 주의사항'].str.replace('1. 다음 환자(부위)에는 사용하지 말 것.','1. 다음 환자(부위)에는 사용하지 말 것')
after4['사용상의 주의사항'] = after4['사용상의 주의사항'].str.replace('2. 다음 환자(부위)에는 사용하지 말 것.','2. 다음 환자(부위)에는 사용하지 말 것')
after4['사용상의 주의사항'] = after4['사용상의 주의사항'].str.replace('3. 다음 환자(부위)에는 사용하지 말 것.','3. 다음 환자(부위)에는 사용하지 말 것')
after4['사용상의 주의사항'] = after4['사용상의 주의사항'].str.replace('4. 다음 환자(부위)에는 사용하지 말 것.','4. 다음 환자(부위)에는 사용하지 말 것')
after4['사용상의 주의사항'] = after4['사용상의 주의사항'].str.replace('5. 다음 환자(부위)에는 사용하지 말 것.','5. 다음 환자(부위)에는 사용하지 말 것')
after4['사용상의 주의사항'] = after4['사용상의 주의사항'].str.replace('6. 다음 환자(부위)에는 사용하지 말 것.','6. 다음 환자(부위)에는 사용하지 말 것')
after4['사용상의 주의사항'] = after4['사용상의 주의사항'].str.replace('7. 다음 환자(부위)에는 사용하지 말 것.','7. 다음 환자(부위)에는 사용하지 말 것')
after4['사용상의 주의사항'] = after4['사용상의 주의사항'].str.replace('8. 다음 환자(부위)에는 사용하지 말 것.','8. 다음 환자(부위)에는 사용하지 말 것')

after4['사용상의 주의사항'] = after4['사용상의 주의사항'].str.replace('1. 다음 환자(부위)에는 사용하지 말 것','■ 다음 환자(부위)에는 사용하지 말 것')
after4['사용상의 주의사항'] = after4['사용상의 주의사항'].str.replace('2. 다음 환자(부위)에는 사용하지 말 것','■ 다음 환자(부위)에는 사용하지 말 것')
after4['사용상의 주의사항'] = after4['사용상의 주의사항'].str.replace('3. 다음 환자(부위)에는 사용하지 말 것','■ 다음 환자(부위)에는 사용하지 말 것')
after4['사용상의 주의사항'] = after4['사용상의 주의사항'].str.replace('4. 다음 환자(부위)에는 사용하지 말 것','■ 다음 환자(부위)에는 사용하지 말 것')
after4['사용상의 주의사항'] = after4['사용상의 주의사항'].str.replace('5. 다음 환자(부위)에는 사용하지 말 것','■ 다음 환자(부위)에는 사용하지 말 것')
after4['사용상의 주의사항'] = after4['사용상의 주의사항'].str.replace('6. 다음 환자(부위)에는 사용하지 말 것','■ 다음 환자(부위)에는 사용하지 말 것')
after4['사용상의 주의사항'] = after4['사용상의 주의사항'].str.replace('7. 다음 환자(부위)에는 사용하지 말 것','■ 다음 환자(부위)에는 사용하지 말 것')
after4['사용상의 주의사항'] = after4['사용상의 주의사항'].str.replace('8. 다음 환자(부위)에는 사용하지 말 것','■ 다음 환자(부위)에는 사용하지 말 것')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   """
# ...

# %%
print(after4['사용상의 주의사항'].unique()[:50])
# Out:
# ['[허가사항변경(2014년 재평가), 의약품안전평가과-943, 2016.02.23.]_x000D_\n_x000D_\n(캡슐제)_x000D_\n■ 다음 환자에게 사용하지 말 것_x000D_\n 1) 이 약 또는 이 약의 구성성분에 과민반응 환자_x000D_\n 2) 두개내압이 상승된 뇌종양 환자_x000D_\n 3) 중증의 간·신장애 환자_x000D_\n 4) 임부 또는 임신하고 있을 가능성이 있는 여성_x000D_\n_x000D_\n■ 이상반응_x000D_\n  구역, 구토, 설사가 나타날 수 있다._x000D_\n_x000D_\n■ 임상검사치에의 영향_x000D_\n  각종 요검사시에 혈당의 검출을 방해할 수 있다. '
#  '[허가사항변경(2014년 재평가), 의약품안전평가과-2589, 2015.11.17]_x000D_\n_x000D_\n(캡슐제)_x000D_\n■ 다음 환자에게 사용하지 말 것_x000D_\n1) 이 약에 과민반응 환자_x000D_\n2) 두개내압이 상승된 뇌종양 환자_x000D_\n3) 중증의 간·신장애 환자_x000D_\n4) 임부 또는 임신하고 있을 가능성이 있는 여성_x000D_\n_x000D_\n■ 이상반응_x000D_\n 구역, 구토, 설사가 나타날 수 있다._x000D_\n_x000D_\n■ 임상검사치에의 영향_x000D_\n  각종 요검사시에 혈당의 검출을 방해할 수 있다.'
#  '■ 다음 환자에게 사용하지 말 것_x000D_\n1) 구성성분에 과민증 환자_x000D_\n2) 두개내압이 상승된 뇌종양 환자_x000D_\n3) 중증의 간·신장애 환자_x000D_\n4) 임부 또는 임신하고 있을 가능성이 있는 부인_x000D_\n_x000D_\n■ 부작용_x000D_\n구역, 구토, 설사가 나타날 수 있다._x000D_\n_x000D_\n■ 임상검사치에의 영향_x000D_\n각종 요검사시에 혈당의 검출을 방해할 수 있다. _x000D_\n  _x000D_\n'
# ...

# %%
after4['사용상의 주의사항'] = after4['사용상의 주의사항'].str.replace("1. 다음 환자(부위)에는 사용하지 말 것.","■ 다음 환자(부위)에는 사용하지 말 것")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   """Entry point for launching an IPython kernel.

# %%
print(after4['사용상의 주의사항'].unique()[:50])
# Out:
# ['[허가사항변경(2014년 재평가), 의약품안전평가과-943, 2016.02.23.]_x000D_\n_x000D_\n(캡슐제)_x000D_\n■ 다음 환자에게 사용하지 말 것_x000D_\n 1) 이 약 또는 이 약의 구성성분에 과민반응 환자_x000D_\n 2) 두개내압이 상승된 뇌종양 환자_x000D_\n 3) 중증의 간·신장애 환자_x000D_\n 4) 임부 또는 임신하고 있을 가능성이 있는 여성_x000D_\n_x000D_\n■ 이상반응_x000D_\n  구역, 구토, 설사가 나타날 수 있다._x000D_\n_x000D_\n■ 임상검사치에의 영향_x000D_\n  각종 요검사시에 혈당의 검출을 방해할 수 있다. '
#  '[허가사항변경(2014년 재평가), 의약품안전평가과-2589, 2015.11.17]_x000D_\n_x000D_\n(캡슐제)_x000D_\n■ 다음 환자에게 사용하지 말 것_x000D_\n1) 이 약에 과민반응 환자_x000D_\n2) 두개내압이 상승된 뇌종양 환자_x000D_\n3) 중증의 간·신장애 환자_x000D_\n4) 임부 또는 임신하고 있을 가능성이 있는 여성_x000D_\n_x000D_\n■ 이상반응_x000D_\n 구역, 구토, 설사가 나타날 수 있다._x000D_\n_x000D_\n■ 임상검사치에의 영향_x000D_\n  각종 요검사시에 혈당의 검출을 방해할 수 있다.'
#  '■ 다음 환자에게 사용하지 말 것_x000D_\n1) 구성성분에 과민증 환자_x000D_\n2) 두개내압이 상승된 뇌종양 환자_x000D_\n3) 중증의 간·신장애 환자_x000D_\n4) 임부 또는 임신하고 있을 가능성이 있는 부인_x000D_\n_x000D_\n■ 부작용_x000D_\n구역, 구토, 설사가 나타날 수 있다._x000D_\n_x000D_\n■ 임상검사치에의 영향_x000D_\n각종 요검사시에 혈당의 검출을 방해할 수 있다. _x000D_\n  _x000D_\n'
# ...

# %%
from google.colab import drive 
drive.mount('/content/gdrive/')
# Out:
# Mounted at /content/gdrive/

# %%
import pandas as pd
data = pd.read_excel('/content/gdrive/MyDrive/캡스톤/coco/약학정보원_20220317_042445 (version 6).xlsx')

# %%
data.head()
# Out:
#    Unnamed: 0                         제품명          보관방법  \
# 0           0          세르복스캡슐 Cerbox Cap.          밀폐용기
# 1           1            셀몬캡슐 Celmon Cap.    기밀용기. 실온보관
# 2           2  스모닌캅셀(수출용) Smonin Capsules     기밀용기,실온보관
# 3           3                 아모닌캡슐(수출용)     밀폐용기, 실온보관
# 4           4          에버닌주 Eburnine Inj.  차광밀봉용기, 실온보관
#
#                                                효능·효과  \
# 0          (캡슐제)\n\n노년기 뇌경화 및 동맥경화에 의한 정신장애, 고혈압망막병증
# 1          (캡슐제)\n\n노년기 뇌경화 및 동맥경화에 의한 정신장애, 고혈압망막병증
# 2  다음 뇌혈관질환의 예방 및 치료 \n\n: 뇌순환부전에 의한 기질적·기능적 증상(기...
# 3  다음 뇌혈관질환의 예방 및 치료 \n\n: 뇌순환부전에 의한 기질적·기능적 증상(기...
# 4  (경구 : 캅셀제)(주사제)\n\n  다음 뇌혈관질환의 예방 및 치료 : 뇌순환부전...
#
#                                                용법·용량  \
# 0  [허가사항변경(2014년 재평가), 의약품안전평가과-943, 2016.02.23.]...
# 1  [허가사항변경(2014년 재평가), 의약품안전평가과-2589, 2015.11.17]...
# 2  성인 1회 1캅셀 1일 3회 경구투여한다. 필요하면 1일 4-6캅셀까지 증량할 수 ...
# 3  성인 1회 1캅셀 1일 3회 경구투여한다. 필요하면 1일 4-6캅셀까지 증량할 수 ...
# ...
